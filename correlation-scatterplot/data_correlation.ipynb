# %% [markdown]
# Data Correlation

# %%
# PANDAS IS FOR DATA WRANGLING
import pandas as pd
import numpy as np

# SEABORN IS A PLOTTING LIBRARY
import seaborn as sns

# MATPLOT LIB IS ALSO A PLOTTING LIBRARY
import matplotlib.pyplot as plt


# Good ol statsmodels
import statsmodels.api as sm

# Specific root mean squared error for stats models
from statsmodels.tools.eval_measures import rmse

# %%
df = pd.read_csv('../dataset/df_only_numeric_value_nov_05.csv')
df.head()
# Out:
#   Primary_Color       Sex  Age Intake_Date Intake_Condition      Intake_Type  \
# 0     BRN TABBY    Spayed    6    12/19/18           NORMAL            STRAY
# 1     BRN TABBY    Spayed    9     10/4/19           NORMAL  OWNER SURRENDER
# 2     ORG TABBY  Neutered   12     6/24/17         ILL MILD            STRAY
# 3     BRN TABBY  Neutered    8     7/13/17           NORMAL            STRAY
# 4    GRAY TABBY    Spayed    8     5/10/17           NORMAL            STRAY
#
#    days_stayed  Primary_Color_encoded  Sex_encoded  Intake_Condition_encoded  \
# 0          799                      5            3                        13
# 1          760                      5            3                        13
# 2          685                     22            2                         7
# 3          666                      5            2                        13
# 4          661                     16            3                        13
#
#    Intake_Type_encoded
# ...

# %%
# Specify the columns of interest
columns_of_interest = ['Primary_Color_encoded', 'Sex_encoded', 'Intake_Condition_encoded', 'Intake_Type_encoded', 'days_stayed']
# Create a new DataFrame with only the specified columns
selected_data = df[columns_of_interest]
# Calculate the correlation matrix
correlation_matrix = selected_data.corr()
# Print correlations with 'days_stayed'
correlation_with_days_stayed = correlation_matrix['days_stayed']
print(correlation_with_days_stayed)
# Out:
# Primary_Color_encoded      -0.034586
# Sex_encoded                 0.077257
# Intake_Condition_encoded    0.007802
# Intake_Type_encoded        -0.045317
# days_stayed                 1.000000
# Name: days_stayed, dtype: float64

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()

# %%
column_to_compare = 'days_stayed'

# Calculate the correlation for each column separately
correlations = df[selected_columns].corrwith(df[column_to_compare])

# Print the correlations
print("Correlation between", column_to_compare, "and other columns:")
print(correlations)
# Out:
# Correlation between days_stayed and other columns:
# days_stayed                 1.000000
# Primary_Color_encoded      -0.034586
# Sex_encoded                 0.077257
# Intake_Condition_encoded    0.007802
# Intake_Type_encoded        -0.045317
# dtype: float64

# %%
# Create a DataFrame from the correlations
correlation_df = pd.DataFrame({'Correlation': correlations})

# Create a heatmap
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f", cbar=False, linewidths=0.5)

plt.title('Correlation Heatmap with days_stayed')
plt.show()

# %%
import pandas as pd

# Read CSV files into DataFrames
intakes_df = pd.read_csv('Austin_Animal_Center_Intakes.csv')
outcomes_df = pd.read_csv('Austin_Animal_Center_Outcomes.csv')

# Check unique 'Animal ID' values before filtering duplicates
print("Unique Animal IDs in Intakes before filtering:", intakes_df['Animal ID'].nunique())
print("Unique Animal IDs in Outcomes before filtering:", outcomes_df['Animal ID'].nunique())

# Drop duplicates based on 'Animal ID' in both DataFrames
intakes_df = intakes_df.drop_duplicates(subset='Animal ID')
outcomes_df = outcomes_df.drop_duplicates(subset='Animal ID')

# Check unique 'Animal ID' values after filtering duplicates
print("Unique Animal IDs in Intakes after filtering:", intakes_df['Animal ID'].nunique())
print("Unique Animal IDs in Outcomes after filtering:", outcomes_df['Animal ID'].nunique())

# Set 'Animal ID' as the index for both DataFrames
intakes_df.set_index('Animal ID', inplace=True)
outcomes_df.set_index('Animal ID', inplace=True)

# Join the intake data with the outcome data based on the index ('Animal ID')
result_df = intakes_df.join(outcomes_df, how='inner', lsuffix='_intakes', rsuffix='_outcomes')

# Check unique 'Animal ID' values after the join
print("Unique Animal IDs in Result:", result_df.index.nunique())
# Out:
# Unique Animal IDs in Intakes before filtering: 58552
# Unique Animal IDs in Outcomes before filtering: 29044
# Unique Animal IDs in Intakes after filtering: 58552
# Unique Animal IDs in Outcomes after filtering: 29044
# Unique Animal IDs in Result: 28745

# %%
intakes_df.shape
# Out:
# (58552, 11)

# %%
outcomes_df.shape
# Out:
# (29044, 11)

# %%
result_df.shape
# Out:
# (28745, 22)

# %%
result_df.duplicated().sum()
# Out:
# 56

# %%
result_df.head()
# Out:
#           Name_intakes        DateTime_intakes MonthYear_intakes  \
# Animal ID
# A664887           *Gia  10/10/2013 01:48:00 PM      October 2013
# A665496          Mikey  10/18/2013 06:07:00 PM      October 2013
# A664936        *Jester  10/11/2013 11:20:00 AM      October 2013
# A665398          Haven  10/17/2013 12:26:00 PM      October 2013
# A665426          Silka  10/17/2013 04:53:00 PM      October 2013
#
#                                    Found Location      Intake Type  \
# Animal ID
# A664887      1901 Onion Creek Pkwy in Austin (TX)            Stray
# A665496          12001 Metric Blvd in Austin (TX)            Stray
# A664936               501 U.S. 183 in Austin (TX)            Stray
# A665398                               Austin (TX)  Owner Surrender
# A665426    8224 Research Blvd #244 in Austin (TX)            Stray
#
#           Intake Condition Animal Type_intakes Sex upon Intake  \
# Animal ID
# A664887             Normal                 Cat   Intact Female
# A665496             Normal                 Cat   Neutered Male
# A664936             Normal                 Cat     Intact Male
# A665398             Normal                 Cat   Intact Female
# A665426             Normal                 Cat     Intact Male
#
#           Age upon Intake             Breed_intakes  ...  \
# Animal ID                                            ...
# A664887           1 month    Domestic Shorthair Mix  ...
# A665496           3 years                    Bengal  ...
# A664936           1 month  Domestic Medium Hair Mix  ...
# A665398           1 month    Domestic Shorthair Mix  ...
# A665426           1 month    Domestic Shorthair Mix  ...
#
#                 DateTime_outcomes MonthYear_outcomes Date of Birth  \
# Animal ID
# A664887    11/10/2013 04:56:00 PM           Nov 2013    08/10/2013
# A665496    10/22/2013 05:54:00 PM           Oct 2013    04/18/2010
# A664936    12/18/2013 06:18:00 PM           Dec 2013    08/18/2013
# A665398    11/10/2013 04:45:00 PM           Nov 2013    08/19/2013
# A665426    11/16/2013 05:09:00 PM           Nov 2013    08/26/2013
#
#           Outcome Type Outcome Subtype Animal Type_outcomes Sex upon Outcome  \
# Animal ID
# A664887       Adoption             NaN                  Cat    Spayed Female
# A665496       Adoption             NaN                  Cat    Neutered Male
# A664936       Adoption             NaN                  Cat    Neutered Male
# A665398       Adoption             NaN                  Cat    Spayed Female
# A665426       Adoption             NaN                  Cat    Neutered Male
#
#           Age upon Outcome            Breed_outcomes Color_outcomes
# Animal ID
# A664887           3 months    Domestic Shorthair Mix          Black
# A665496            3 years                    Bengal    Brown Tiger
# A664936           4 months  Domestic Medium Hair Mix    Brown Tabby
# A665398           2 months    Domestic Shorthair Mix     White/Blue
# A665426           2 months    Domestic Shorthair Mix          Black
#
# [5 rows x 22 columns]

# %%
# Reset the index to include 'Animal ID' as a column
result_df.reset_index(inplace=True)
result_df.to_csv("../dataset/Texas_Intake_and_Outcome.csv", index = False)

# %%
result_df.duplicated().sum()
# Out:
# 0

# %%
# Read CSV 
reading = pd.read_csv("../dataset/Texas_Intake_and_Outcome.csv")
reading.head()
# Out:
#   Name_intakes        DateTime_intakes MonthYear_intakes  \
# 0         *Gia  10/10/2013 01:48:00 PM      October 2013
# 1        Mikey  10/18/2013 06:07:00 PM      October 2013
# 2      *Jester  10/11/2013 11:20:00 AM      October 2013
# 3        Haven  10/17/2013 12:26:00 PM      October 2013
# 4        Silka  10/17/2013 04:53:00 PM      October 2013
#
#                            Found Location      Intake Type Intake Condition  \
# 0    1901 Onion Creek Pkwy in Austin (TX)            Stray           Normal
# 1        12001 Metric Blvd in Austin (TX)            Stray           Normal
# 2             501 U.S. 183 in Austin (TX)            Stray           Normal
# 3                             Austin (TX)  Owner Surrender           Normal
# 4  8224 Research Blvd #244 in Austin (TX)            Stray           Normal
#
#   Animal Type_intakes Sex upon Intake Age upon Intake  \
# 0                 Cat   Intact Female         1 month
# 1                 Cat   Neutered Male         3 years
# 2                 Cat     Intact Male         1 month
# 3                 Cat   Intact Female         1 month
# 4                 Cat     Intact Male         1 month
#
#               Breed_intakes  ...       DateTime_outcomes MonthYear_outcomes  \
# 0    Domestic Shorthair Mix  ...  11/10/2013 04:56:00 PM           Nov 2013
# 1                    Bengal  ...  10/22/2013 05:54:00 PM           Oct 2013
# 2  Domestic Medium Hair Mix  ...  12/18/2013 06:18:00 PM           Dec 2013
# 3    Domestic Shorthair Mix  ...  11/10/2013 04:45:00 PM           Nov 2013
# 4    Domestic Shorthair Mix  ...  11/16/2013 05:09:00 PM           Nov 2013
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type_outcomes  \
# 0    08/10/2013     Adoption             NaN                  Cat
# 1    04/18/2010     Adoption             NaN                  Cat
# 2    08/18/2013     Adoption             NaN                  Cat
# 3    08/19/2013     Adoption             NaN                  Cat
# 4    08/26/2013     Adoption             NaN                  Cat
#
#   Sex upon Outcome Age upon Outcome            Breed_outcomes Color_outcomes
# 0    Spayed Female         3 months    Domestic Shorthair Mix          Black
# 1    Neutered Male          3 years                    Bengal    Brown Tiger
# 2    Neutered Male         4 months  Domestic Medium Hair Mix    Brown Tabby
# 3    Spayed Female         2 months    Domestic Shorthair Mix     White/Blue
# 4    Neutered Male         2 months    Domestic Shorthair Mix          Black
#
# [5 rows x 22 columns]

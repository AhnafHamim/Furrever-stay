# %%
# Our data management libraries
import pandas as pd
import numpy as np

# A basic visualization library
import matplotlib.pyplot as plt

# A great visualization library
import seaborn as sns

# Very important, this will make your charts appear in your notebook instead of in a new window.
# %matplotlib inline
from datetime import datetime


# Seaborn / matplotlib for visualization 
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../new_dataset/Texas_Intake_and_Outcome.csv')
df.head(5)
# Out:
#   Animal ID Name_intakes        DateTime_intakes MonthYear_intakes  \
# 0   A664887         *Gia  10/10/2013 01:48:00 PM      October 2013
# 1   A665496        Mikey  10/18/2013 06:07:00 PM      October 2013
# 2   A664936      *Jester  10/11/2013 11:20:00 AM      October 2013
# 3   A665398        Haven  10/17/2013 12:26:00 PM      October 2013
# 4   A665426        Silka  10/17/2013 04:53:00 PM      October 2013
#
#                            Found Location      Intake Type Intake Condition  \
# 0    1901 Onion Creek Pkwy in Austin (TX)            Stray           Normal
# 1        12001 Metric Blvd in Austin (TX)            Stray           Normal
# 2             501 U.S. 183 in Austin (TX)            Stray           Normal
# 3                             Austin (TX)  Owner Surrender           Normal
# 4  8224 Research Blvd #244 in Austin (TX)            Stray           Normal
#
#   Animal Type_intakes Sex upon Intake Age upon Intake  ...  \
# 0                 Cat   Intact Female         1 month  ...
# 1                 Cat   Neutered Male         3 years  ...
# 2                 Cat     Intact Male         1 month  ...
# 3                 Cat   Intact Female         1 month  ...
# 4                 Cat     Intact Male         1 month  ...
#
#         DateTime_outcomes MonthYear_outcomes Date of Birth Outcome Type  \
# 0  11/10/2013 04:56:00 PM           Nov 2013    08/10/2013     Adoption
# 1  10/22/2013 05:54:00 PM           Oct 2013    04/18/2010     Adoption
# 2  12/18/2013 06:18:00 PM           Dec 2013    08/18/2013     Adoption
# 3  11/10/2013 04:45:00 PM           Nov 2013    08/19/2013     Adoption
# 4  11/16/2013 05:09:00 PM           Nov 2013    08/26/2013     Adoption
#
#   Outcome Subtype Animal Type_outcomes Sex upon Outcome Age upon Outcome  \
# 0             NaN                  Cat    Spayed Female         3 months
# 1             NaN                  Cat    Neutered Male          3 years
# 2             NaN                  Cat    Neutered Male         4 months
# 3             NaN                  Cat    Spayed Female         2 months
# 4             NaN                  Cat    Neutered Male         2 months
#
#              Breed_outcomes Color_outcomes
# 0    Domestic Shorthair Mix          Black
# 1                    Bengal    Brown Tiger
# 2  Domestic Medium Hair Mix    Brown Tabby
# 3    Domestic Shorthair Mix     White/Blue
# 4    Domestic Shorthair Mix          Black
#
# [5 rows x 23 columns]

# %%
# List of columns to drop outcome subtype is dropped because getting rid 
#of the nulls for it takes wayyyyy too many samples and it doesnt really matter because
#we have outcome type as adoption UNLESS YOU WANT TO THINK OF OUTCOME SUBTYPE = FOSTER AS NOT REAL ADOPTION
#OUTCOME SUBTYPE IS MOSTLY EMPTY BECAUSE SOMETIMES THEY ARE ADOPTED AND THATS IT
columns_to_drop = ['Found Location', 'Animal Type_intakes', 'Name_intakes',
                   'Name_outcomes','Breed_outcomes','Color_outcomes','Animal Type_outcomes',
                   'MonthYear_intakes','MonthYear_outcomes','Outcome Subtype']

# Drop the specified columns
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.tail(50)
# Out:
#       Animal ID        DateTime_intakes      Intake Type Intake Condition  \
# 28695   A890657  10/10/2023 03:21:00 PM            Stray           Normal
# 28696   A889226  09/19/2023 08:04:00 AM            Stray          Injured
# 28697   A889153  09/18/2023 12:15:00 PM            Stray          Injured
# 28698   A833244  04/26/2021 04:14:00 PM            Stray           Normal
# 28699   A889463  09/22/2023 02:36:00 PM            Stray           Normal
# 28700   A893338  11/19/2023 06:23:00 PM  Owner Surrender           Normal
# 28701   A881888  05/28/2023 12:39:00 PM            Stray           Normal
# 28702   A893178  11/16/2023 02:39:00 PM            Stray           Normal
# 28703   A891300  10/20/2023 10:39:00 AM            Stray           Normal
# 28704   A890791  10/12/2023 01:03:00 PM            Stray           Normal
# 28705   A892514  11/07/2023 12:03:00 PM  Owner Surrender           Normal
# 28706   A892206  11/02/2023 02:26:00 PM            Stray             Sick
# 28707   A891117  10/17/2023 02:20:00 PM            Stray           Normal
# 28708   A891448  10/23/2023 11:50:00 AM            Stray           Normal
# 28709   A891106  10/17/2023 01:59:00 PM            Stray           Normal
# 28710   A892556  11/07/2023 03:32:00 PM            Stray           Normal
# 28711   A891332  10/20/2023 02:08:00 PM            Stray           Normal
# 28712   A892174  11/02/2023 01:27:00 PM    Public Assist           Normal
# 28713   A890661  10/10/2023 03:21:00 PM            Stray           Normal
# 28714   A889325  09/20/2023 03:21:00 PM            Stray           Normal
# 28715   A891005  10/16/2023 11:30:00 AM            Stray           Normal
# 28716   A891469  10/23/2023 02:22:00 PM            Stray           Normal
# 28717   A893248  11/17/2023 06:00:00 PM            Stray           Normal
# 28718   A675395  11/10/2023 02:31:00 PM            Stray          Injured
# 28719   A893520  11/22/2023 12:57:00 PM  Owner Surrender           Normal
# 28720   A893485  11/22/2023 08:21:00 AM            Stray             Sick
# 28721   A889897  09/29/2023 11:05:00 AM            Stray           Normal
# 28722   A892557  11/07/2023 03:32:00 PM            Stray           Normal
# 28723   A892203  11/02/2023 02:26:00 PM            Stray             Sick
# 28724   A892589  11/07/2023 05:27:00 PM  Owner Surrender           Normal
# 28725   A893030  11/14/2023 03:08:00 PM            Stray           Normal
# 28726   A893227  11/17/2023 12:35:00 PM            Stray           Normal
# 28727   A893225  11/17/2023 12:35:00 PM            Stray           Normal
# 28728   A893224  11/17/2023 12:35:00 PM            Stray           Normal
# 28729   A893177  11/16/2023 02:05:00 PM            Stray           Normal
# 28730   A893200  11/16/2023 05:28:00 PM            Stray           Normal
# 28731   A890574  10/09/2023 12:53:00 PM            Stray           Normal
# 28732   A892455  11/06/2023 01:33:00 PM  Owner Surrender           Normal
# 28733   A881685  05/25/2023 11:05:00 AM            Stray           Normal
# 28734   A891245  10/19/2023 02:03:00 PM            Stray           Normal
# 28735   A891292  10/20/2023 10:28:00 AM        Abandoned           Normal
# 28736   A893391  11/21/2023 07:21:00 AM  Owner Surrender          Injured
# 28737   A890815  11/27/2023 11:22:00 AM  Owner Surrender           Normal
# 28738   A890817  10/12/2023 05:52:00 PM  Owner Surrender           Normal
# 28739   A891711  10/26/2023 03:49:00 PM  Owner Surrender           Normal
# 28740   A796115  05/29/2019 11:04:00 AM            Stray           Normal
# 28741   A892826  11/11/2023 09:32:00 AM            Stray           Normal
# 28742   A885026  07/12/2023 11:49:00 AM            Stray         Neonatal
# 28743   A893396  11/20/2023 08:13:00 PM  Owner Surrender           Normal
# 28744   A891867  10/28/2023 02:26:00 PM            Stray           Normal
#
#       Sex upon Intake Age upon Intake           Breed_intakes  \
# 28695   Intact Female         2 years  Domestic Shorthair Mix
# 28696     Intact Male        2 months      Domestic Shorthair
# 28697     Intact Male         1 month      Domestic Shorthair
# 28698   Intact Female         2 years      Domestic Shorthair
# 28699     Intact Male         1 month      Domestic Shorthair
# 28700   Spayed Female         3 years       Domestic Longhair
# 28701   Spayed Female         8 years      Domestic Shorthair
# 28702   Neutered Male         2 years    Domestic Medium Hair
# 28703   Intact Female        2 months      Domestic Shorthair
# 28704   Intact Female        3 months      Domestic Shorthair
# 28705   Intact Female        3 months      Domestic Shorthair
# 28706   Intact Female         1 month      Domestic Shorthair
# 28707     Intact Male        2 months      Domestic Shorthair
# 28708     Intact Male         1 month      Domestic Shorthair
# 28709   Intact Female        2 months      Domestic Shorthair
# 28710   Intact Female        3 months      Domestic Shorthair
# 28711     Intact Male        2 months      Domestic Shorthair
# 28712   Intact Female         2 years      Domestic Shorthair
# 28713     Intact Male         1 month  Domestic Shorthair Mix
# 28714     Intact Male        2 months      Domestic Shorthair
# 28715   Intact Female         4 weeks      Domestic Shorthair
# 28716   Intact Female        4 months      Domestic Shorthair
# 28717   Spayed Female          1 year      Domestic Shorthair
# 28718   Spayed Female          1 year      Domestic Shorthair
# 28719     Intact Male         2 years      Domestic Shorthair
# 28720     Intact Male         1 month      Domestic Shorthair
# 28721   Intact Female         4 weeks      Domestic Shorthair
# 28722   Intact Female        3 months      Domestic Shorthair
# 28723     Intact Male         1 month      Domestic Shorthair
# 28724     Intact Male         2 years      Domestic Shorthair
# 28725     Intact Male         1 month      Domestic Shorthair
# 28726   Intact Female         1 month      Domestic Shorthair
# 28727   Intact Female         1 month      Domestic Shorthair
# 28728     Intact Male         1 month      Domestic Shorthair
# 28729     Intact Male          1 year      Domestic Shorthair
# 28730     Intact Male        2 months      Domestic Shorthair
# 28731   Intact Female         3 weeks      Domestic Shorthair
# 28732   Intact Female        7 months      Domestic Shorthair
# 28733     Intact Male         3 weeks      Domestic Shorthair
# 28734   Intact Female          1 year      Domestic Shorthair
# 28735   Intact Female         1 month      Domestic Shorthair
# 28736   Neutered Male         2 years      Domestic Shorthair
# 28737   Neutered Male        2 months      Domestic Shorthair
# 28738     Intact Male         1 month      Domestic Shorthair
# 28739     Intact Male        4 months      Domestic Shorthair
# 28740   Intact Female         1 month  Domestic Shorthair Mix
# 28741     Intact Male       11 months      Domestic Shorthair
# 28742     Intact Male          4 days      Domestic Shorthair
# 28743   Spayed Female         3 years      Domestic Shorthair
# 28744   Intact Female         1 month      Domestic Shorthair
#
#             Color_intakes       DateTime_outcomes Date of Birth Outcome Type  \
# 28695  White/Orange Tabby  11/22/2023 05:12:00 PM    10/10/2021     Adoption
# 28696         Black/White  11/20/2023 12:11:00 PM    07/19/2023     Adoption
# 28697               Black  11/20/2023 12:12:00 PM    07/26/2023     Adoption
# 28698        Orange Tabby  04/30/2021 06:09:00 PM    04/26/2019     Adoption
# 28699         Black/White  11/19/2023 10:47:00 AM    08/12/2023     Adoption
# 28700        Orange/White  11/21/2023 04:01:00 PM    11/19/2020     Adoption
# 28701         Brown Tabby  11/21/2023 10:12:00 AM    05/01/2015     Adoption
# 28702         Cream Tabby  11/20/2023 12:01:00 PM    11/16/2021     Adoption
# 28703         Brown Tabby  11/20/2023 03:27:00 PM    08/13/2023     Adoption
# 28704              Tortie  10/16/2023 05:07:00 PM    07/12/2023     Adoption
# 28705          Blue Tabby  11/22/2023 07:44:00 AM    08/07/2023     Adoption
# 28706        Calico/White  11/20/2023 05:20:00 PM    09/02/2023     Adoption
# 28707        Orange Tabby  11/20/2023 05:39:00 PM    07/26/2023     Adoption
# 28708        Orange Tabby  11/20/2023 05:10:00 PM    08/23/2023     Adoption
# 28709              Torbie  11/20/2023 05:55:00 PM    07/24/2023     Adoption
# 28710         Brown Tabby  11/20/2023 05:04:00 PM    07/29/2023     Adoption
# 28711         Black/White  11/20/2023 06:35:00 PM    08/12/2023     Adoption
# 28712         Black/White  11/20/2023 06:42:00 PM    11/02/2021     Adoption
# 28713  Orange Tabby/White  11/21/2023 05:58:00 PM    09/03/2023     Adoption
# 28714         Brown Tabby  11/22/2023 08:24:00 AM    07/15/2023     Adoption
# 28715               Black  11/27/2023 12:26:00 PM    09/14/2023     Adoption
# 28716         Brown Tabby  11/21/2023 06:58:00 PM    06/23/2023     Adoption
# 28717         Brown Tabby  11/25/2023 03:10:00 PM    11/17/2022     Adoption
# 28718              Calico  11/26/2023 12:23:00 PM    08/25/2022     Adoption
# 28719               White  11/27/2023 01:38:00 PM    11/22/2021     Adoption
# 28720    Lynx Point/White  11/28/2023 01:22:00 PM    09/22/2023     Adoption
# 28721         Cream Tabby  11/22/2023 04:08:00 PM    09/01/2023     Adoption
# 28722              Torbie  11/22/2023 04:52:00 PM    07/29/2023     Adoption
# 28723        Orange Tabby  11/22/2023 05:49:00 PM    09/02/2023     Adoption
# 28724         Cream Tabby  11/22/2023 05:24:00 PM    11/07/2021     Adoption
# 28725               Black  11/25/2023 11:06:00 AM    09/23/2023     Adoption
# 28726        Torbie/White  11/25/2023 12:26:00 PM    09/17/2023     Adoption
# 28727        Orange Tabby  11/25/2023 12:44:00 PM    09/17/2023     Adoption
# 28728               Black  11/25/2023 03:04:00 PM    09/17/2023     Adoption
# 28729         Brown Tabby  11/25/2023 02:55:00 PM    11/16/2022     Adoption
# 28730         Brown Tabby  11/25/2023 03:52:00 PM    09/04/2023     Adoption
# 28731              Torbie  11/25/2023 03:42:00 PM    09/17/2023     Adoption
# 28732   Brown Tabby/White  11/27/2023 05:20:00 PM    04/06/2023     Adoption
# 28733         Brown Tabby  07/26/2023 05:51:00 PM    05/01/2023     Adoption
# 28734              Tortie  10/26/2023 02:38:00 PM    10/19/2022     Adoption
# 28735              Tortie  11/17/2023 04:55:00 PM    09/05/2023     Adoption
# 28736    Blue Tabby/White  11/28/2023 05:16:00 PM    11/20/2021     Adoption
# 28737         Black/White  11/20/2023 11:45:00 AM    09/06/2023     Adoption
# 28738         Black/White  11/20/2023 11:47:00 AM    09/06/2023     Adoption
# 28739          Blue Tabby  11/02/2023 06:15:00 PM    06/26/2023     Adoption
# 28740         Brown Tabby  06/04/2019 05:27:00 PM    03/29/2019     Adoption
# 28741          White/Gray  11/27/2023 05:14:00 PM    12/11/2022     Adoption
# 28742         Brown Tabby  09/25/2023 04:48:00 PM    07/08/2023     Adoption
# 28743              Calico  11/28/2023 04:19:00 PM    11/20/2020     Adoption
# 28744          Blue Tabby  11/28/2023 05:39:00 PM    08/28/2023     Adoption
#
#       Sex upon Outcome Age upon Outcome
# 28695    Spayed Female          2 years
# 28696    Neutered Male         4 months
# 28697    Neutered Male         3 months
# 28698    Spayed Female          2 years
# 28699    Neutered Male         3 months
# 28700    Spayed Female          3 years
# 28701    Spayed Female          8 years
# 28702    Neutered Male          2 years
# 28703    Spayed Female         3 months
# 28704    Intact Female         3 months
# 28705    Spayed Female         3 months
# 28706    Spayed Female         2 months
# 28707    Neutered Male         3 months
# 28708    Neutered Male         2 months
# 28709    Spayed Female         3 months
# 28710    Spayed Female         3 months
# 28711    Neutered Male         3 months
# 28712    Spayed Female          2 years
# 28713    Neutered Male         2 months
# 28714    Neutered Male         4 months
# 28715    Spayed Female         2 months
# 28716    Spayed Female         4 months
# 28717    Spayed Female           1 year
# 28718    Spayed Female           1 year
# 28719      Intact Male          2 years
# 28720      Intact Male         2 months
# 28721    Spayed Female         2 months
# 28722    Spayed Female         3 months
# 28723    Neutered Male         2 months
# 28724    Neutered Male          2 years
# 28725    Neutered Male         2 months
# 28726    Spayed Female         2 months
# 28727    Spayed Female         2 months
# 28728    Neutered Male         2 months
# 28729    Neutered Male           1 year
# 28730    Neutered Male         2 months
# 28731    Spayed Female         2 months
# 28732    Spayed Female         7 months
# 28733      Intact Male         2 months
# 28734    Intact Female           1 year
# 28735    Spayed Female         2 months
# 28736    Neutered Male          2 years
# 28737    Neutered Male         2 months
# 28738    Neutered Male         2 months
# 28739    Neutered Male         4 months
# 28740    Spayed Female         2 months
# 28741    Neutered Male        11 months
# 28742    Neutered Male         2 months
# 28743    Spayed Female          3 years
# 28744    Spayed Female         3 months

# %%
columns_to_rename = {
    'DateTime_intakes': 'date_intake',
    'Intake Type': 'intake_type',
    'Intake Condition': 'intake_condition',
    'Sex upon Intake': 'sex_intake',
    'Age upon Intake': 'age_intake',
    'Breed_intakes':'breed',
    'Color_intakes':'color',
    'DateTime_outcomes':'date_outcome',
    'Date of Birth':'dob',
    'Outcome Type':'outcome_type',
    'Outcome Subtype':'outcome_subtype',
    'Sex upon Outcome':'sex_outcome',
    'Age upon Outcome':'age_outcome'
    
}

# Rename the specified columns
df.rename(columns=columns_to_rename, inplace=True)

# %%
#i dropped duplicate ids on before joining them, dont drop duplicates because cats have same names or dates and we might lose samples
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Animal ID           0
# date_intake         0
# intake_type         0
# intake_condition    0
# sex_intake          0
# age_intake          0
# breed               0
# color               0
# date_outcome        0
# dob                 0
# outcome_type        0
# sex_outcome         0
# age_outcome         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Animal ID           0
# date_intake         0
# intake_type         0
# intake_condition    0
# sex_intake          0
# age_intake          0
# breed               0
# color               0
# date_outcome        0
# dob                 0
# outcome_type        0
# sex_outcome         0
# age_outcome         0
# dtype: int64

# %%
df.tail(50)
# Out:
#       Animal ID             date_intake      intake_type intake_condition  \
# 28695   A890657  10/10/2023 03:21:00 PM            Stray           Normal
# 28696   A889226  09/19/2023 08:04:00 AM            Stray          Injured
# 28697   A889153  09/18/2023 12:15:00 PM            Stray          Injured
# 28698   A833244  04/26/2021 04:14:00 PM            Stray           Normal
# 28699   A889463  09/22/2023 02:36:00 PM            Stray           Normal
# 28700   A893338  11/19/2023 06:23:00 PM  Owner Surrender           Normal
# 28701   A881888  05/28/2023 12:39:00 PM            Stray           Normal
# 28702   A893178  11/16/2023 02:39:00 PM            Stray           Normal
# 28703   A891300  10/20/2023 10:39:00 AM            Stray           Normal
# 28704   A890791  10/12/2023 01:03:00 PM            Stray           Normal
# 28705   A892514  11/07/2023 12:03:00 PM  Owner Surrender           Normal
# 28706   A892206  11/02/2023 02:26:00 PM            Stray             Sick
# 28707   A891117  10/17/2023 02:20:00 PM            Stray           Normal
# 28708   A891448  10/23/2023 11:50:00 AM            Stray           Normal
# 28709   A891106  10/17/2023 01:59:00 PM            Stray           Normal
# 28710   A892556  11/07/2023 03:32:00 PM            Stray           Normal
# 28711   A891332  10/20/2023 02:08:00 PM            Stray           Normal
# 28712   A892174  11/02/2023 01:27:00 PM    Public Assist           Normal
# 28713   A890661  10/10/2023 03:21:00 PM            Stray           Normal
# 28714   A889325  09/20/2023 03:21:00 PM            Stray           Normal
# 28715   A891005  10/16/2023 11:30:00 AM            Stray           Normal
# 28716   A891469  10/23/2023 02:22:00 PM            Stray           Normal
# 28717   A893248  11/17/2023 06:00:00 PM            Stray           Normal
# 28718   A675395  11/10/2023 02:31:00 PM            Stray          Injured
# 28719   A893520  11/22/2023 12:57:00 PM  Owner Surrender           Normal
# 28720   A893485  11/22/2023 08:21:00 AM            Stray             Sick
# 28721   A889897  09/29/2023 11:05:00 AM            Stray           Normal
# 28722   A892557  11/07/2023 03:32:00 PM            Stray           Normal
# 28723   A892203  11/02/2023 02:26:00 PM            Stray             Sick
# 28724   A892589  11/07/2023 05:27:00 PM  Owner Surrender           Normal
# 28725   A893030  11/14/2023 03:08:00 PM            Stray           Normal
# 28726   A893227  11/17/2023 12:35:00 PM            Stray           Normal
# 28727   A893225  11/17/2023 12:35:00 PM            Stray           Normal
# 28728   A893224  11/17/2023 12:35:00 PM            Stray           Normal
# 28729   A893177  11/16/2023 02:05:00 PM            Stray           Normal
# 28730   A893200  11/16/2023 05:28:00 PM            Stray           Normal
# 28731   A890574  10/09/2023 12:53:00 PM            Stray           Normal
# 28732   A892455  11/06/2023 01:33:00 PM  Owner Surrender           Normal
# 28733   A881685  05/25/2023 11:05:00 AM            Stray           Normal
# 28734   A891245  10/19/2023 02:03:00 PM            Stray           Normal
# 28735   A891292  10/20/2023 10:28:00 AM        Abandoned           Normal
# 28736   A893391  11/21/2023 07:21:00 AM  Owner Surrender          Injured
# 28737   A890815  11/27/2023 11:22:00 AM  Owner Surrender           Normal
# 28738   A890817  10/12/2023 05:52:00 PM  Owner Surrender           Normal
# 28739   A891711  10/26/2023 03:49:00 PM  Owner Surrender           Normal
# 28740   A796115  05/29/2019 11:04:00 AM            Stray           Normal
# 28741   A892826  11/11/2023 09:32:00 AM            Stray           Normal
# 28742   A885026  07/12/2023 11:49:00 AM            Stray         Neonatal
# 28743   A893396  11/20/2023 08:13:00 PM  Owner Surrender           Normal
# 28744   A891867  10/28/2023 02:26:00 PM            Stray           Normal
#
#           sex_intake age_intake                   breed               color  \
# 28695  Intact Female    2 years  Domestic Shorthair Mix  White/Orange Tabby
# 28696    Intact Male   2 months      Domestic Shorthair         Black/White
# 28697    Intact Male    1 month      Domestic Shorthair               Black
# 28698  Intact Female    2 years      Domestic Shorthair        Orange Tabby
# 28699    Intact Male    1 month      Domestic Shorthair         Black/White
# 28700  Spayed Female    3 years       Domestic Longhair        Orange/White
# 28701  Spayed Female    8 years      Domestic Shorthair         Brown Tabby
# 28702  Neutered Male    2 years    Domestic Medium Hair         Cream Tabby
# 28703  Intact Female   2 months      Domestic Shorthair         Brown Tabby
# 28704  Intact Female   3 months      Domestic Shorthair              Tortie
# 28705  Intact Female   3 months      Domestic Shorthair          Blue Tabby
# 28706  Intact Female    1 month      Domestic Shorthair        Calico/White
# 28707    Intact Male   2 months      Domestic Shorthair        Orange Tabby
# 28708    Intact Male    1 month      Domestic Shorthair        Orange Tabby
# 28709  Intact Female   2 months      Domestic Shorthair              Torbie
# 28710  Intact Female   3 months      Domestic Shorthair         Brown Tabby
# 28711    Intact Male   2 months      Domestic Shorthair         Black/White
# 28712  Intact Female    2 years      Domestic Shorthair         Black/White
# 28713    Intact Male    1 month  Domestic Shorthair Mix  Orange Tabby/White
# 28714    Intact Male   2 months      Domestic Shorthair         Brown Tabby
# 28715  Intact Female    4 weeks      Domestic Shorthair               Black
# 28716  Intact Female   4 months      Domestic Shorthair         Brown Tabby
# 28717  Spayed Female     1 year      Domestic Shorthair         Brown Tabby
# 28718  Spayed Female     1 year      Domestic Shorthair              Calico
# 28719    Intact Male    2 years      Domestic Shorthair               White
# 28720    Intact Male    1 month      Domestic Shorthair    Lynx Point/White
# 28721  Intact Female    4 weeks      Domestic Shorthair         Cream Tabby
# 28722  Intact Female   3 months      Domestic Shorthair              Torbie
# 28723    Intact Male    1 month      Domestic Shorthair        Orange Tabby
# 28724    Intact Male    2 years      Domestic Shorthair         Cream Tabby
# 28725    Intact Male    1 month      Domestic Shorthair               Black
# 28726  Intact Female    1 month      Domestic Shorthair        Torbie/White
# 28727  Intact Female    1 month      Domestic Shorthair        Orange Tabby
# 28728    Intact Male    1 month      Domestic Shorthair               Black
# 28729    Intact Male     1 year      Domestic Shorthair         Brown Tabby
# 28730    Intact Male   2 months      Domestic Shorthair         Brown Tabby
# 28731  Intact Female    3 weeks      Domestic Shorthair              Torbie
# 28732  Intact Female   7 months      Domestic Shorthair   Brown Tabby/White
# 28733    Intact Male    3 weeks      Domestic Shorthair         Brown Tabby
# 28734  Intact Female     1 year      Domestic Shorthair              Tortie
# 28735  Intact Female    1 month      Domestic Shorthair              Tortie
# 28736  Neutered Male    2 years      Domestic Shorthair    Blue Tabby/White
# 28737  Neutered Male   2 months      Domestic Shorthair         Black/White
# 28738    Intact Male    1 month      Domestic Shorthair         Black/White
# 28739    Intact Male   4 months      Domestic Shorthair          Blue Tabby
# 28740  Intact Female    1 month  Domestic Shorthair Mix         Brown Tabby
# 28741    Intact Male  11 months      Domestic Shorthair          White/Gray
# 28742    Intact Male     4 days      Domestic Shorthair         Brown Tabby
# 28743  Spayed Female    3 years      Domestic Shorthair              Calico
# 28744  Intact Female    1 month      Domestic Shorthair          Blue Tabby
#
#                  date_outcome         dob outcome_type    sex_outcome  \
# 28695  11/22/2023 05:12:00 PM  10/10/2021     Adoption  Spayed Female
# 28696  11/20/2023 12:11:00 PM  07/19/2023     Adoption  Neutered Male
# 28697  11/20/2023 12:12:00 PM  07/26/2023     Adoption  Neutered Male
# 28698  04/30/2021 06:09:00 PM  04/26/2019     Adoption  Spayed Female
# 28699  11/19/2023 10:47:00 AM  08/12/2023     Adoption  Neutered Male
# 28700  11/21/2023 04:01:00 PM  11/19/2020     Adoption  Spayed Female
# 28701  11/21/2023 10:12:00 AM  05/01/2015     Adoption  Spayed Female
# 28702  11/20/2023 12:01:00 PM  11/16/2021     Adoption  Neutered Male
# 28703  11/20/2023 03:27:00 PM  08/13/2023     Adoption  Spayed Female
# 28704  10/16/2023 05:07:00 PM  07/12/2023     Adoption  Intact Female
# 28705  11/22/2023 07:44:00 AM  08/07/2023     Adoption  Spayed Female
# 28706  11/20/2023 05:20:00 PM  09/02/2023     Adoption  Spayed Female
# 28707  11/20/2023 05:39:00 PM  07/26/2023     Adoption  Neutered Male
# 28708  11/20/2023 05:10:00 PM  08/23/2023     Adoption  Neutered Male
# 28709  11/20/2023 05:55:00 PM  07/24/2023     Adoption  Spayed Female
# 28710  11/20/2023 05:04:00 PM  07/29/2023     Adoption  Spayed Female
# 28711  11/20/2023 06:35:00 PM  08/12/2023     Adoption  Neutered Male
# 28712  11/20/2023 06:42:00 PM  11/02/2021     Adoption  Spayed Female
# 28713  11/21/2023 05:58:00 PM  09/03/2023     Adoption  Neutered Male
# 28714  11/22/2023 08:24:00 AM  07/15/2023     Adoption  Neutered Male
# 28715  11/27/2023 12:26:00 PM  09/14/2023     Adoption  Spayed Female
# 28716  11/21/2023 06:58:00 PM  06/23/2023     Adoption  Spayed Female
# 28717  11/25/2023 03:10:00 PM  11/17/2022     Adoption  Spayed Female
# 28718  11/26/2023 12:23:00 PM  08/25/2022     Adoption  Spayed Female
# 28719  11/27/2023 01:38:00 PM  11/22/2021     Adoption    Intact Male
# 28720  11/28/2023 01:22:00 PM  09/22/2023     Adoption    Intact Male
# 28721  11/22/2023 04:08:00 PM  09/01/2023     Adoption  Spayed Female
# 28722  11/22/2023 04:52:00 PM  07/29/2023     Adoption  Spayed Female
# 28723  11/22/2023 05:49:00 PM  09/02/2023     Adoption  Neutered Male
# 28724  11/22/2023 05:24:00 PM  11/07/2021     Adoption  Neutered Male
# 28725  11/25/2023 11:06:00 AM  09/23/2023     Adoption  Neutered Male
# 28726  11/25/2023 12:26:00 PM  09/17/2023     Adoption  Spayed Female
# 28727  11/25/2023 12:44:00 PM  09/17/2023     Adoption  Spayed Female
# 28728  11/25/2023 03:04:00 PM  09/17/2023     Adoption  Neutered Male
# 28729  11/25/2023 02:55:00 PM  11/16/2022     Adoption  Neutered Male
# 28730  11/25/2023 03:52:00 PM  09/04/2023     Adoption  Neutered Male
# 28731  11/25/2023 03:42:00 PM  09/17/2023     Adoption  Spayed Female
# 28732  11/27/2023 05:20:00 PM  04/06/2023     Adoption  Spayed Female
# 28733  07/26/2023 05:51:00 PM  05/01/2023     Adoption    Intact Male
# 28734  10/26/2023 02:38:00 PM  10/19/2022     Adoption  Intact Female
# 28735  11/17/2023 04:55:00 PM  09/05/2023     Adoption  Spayed Female
# 28736  11/28/2023 05:16:00 PM  11/20/2021     Adoption  Neutered Male
# 28737  11/20/2023 11:45:00 AM  09/06/2023     Adoption  Neutered Male
# 28738  11/20/2023 11:47:00 AM  09/06/2023     Adoption  Neutered Male
# 28739  11/02/2023 06:15:00 PM  06/26/2023     Adoption  Neutered Male
# 28740  06/04/2019 05:27:00 PM  03/29/2019     Adoption  Spayed Female
# 28741  11/27/2023 05:14:00 PM  12/11/2022     Adoption  Neutered Male
# 28742  09/25/2023 04:48:00 PM  07/08/2023     Adoption  Neutered Male
# 28743  11/28/2023 04:19:00 PM  11/20/2020     Adoption  Spayed Female
# 28744  11/28/2023 05:39:00 PM  08/28/2023     Adoption  Spayed Female
#
#       age_outcome
# 28695     2 years
# 28696    4 months
# 28697    3 months
# 28698     2 years
# 28699    3 months
# 28700     3 years
# 28701     8 years
# 28702     2 years
# 28703    3 months
# 28704    3 months
# 28705    3 months
# 28706    2 months
# 28707    3 months
# 28708    2 months
# 28709    3 months
# 28710    3 months
# 28711    3 months
# 28712     2 years
# 28713    2 months
# 28714    4 months
# 28715    2 months
# 28716    4 months
# 28717      1 year
# 28718      1 year
# 28719     2 years
# 28720    2 months
# 28721    2 months
# 28722    3 months
# 28723    2 months
# 28724     2 years
# 28725    2 months
# 28726    2 months
# 28727    2 months
# 28728    2 months
# 28729      1 year
# 28730    2 months
# 28731    2 months
# 28732    7 months
# 28733    2 months
# 28734      1 year
# 28735    2 months
# 28736     2 years
# 28737    2 months
# 28738    2 months
# 28739    4 months
# 28740    2 months
# 28741   11 months
# 28742    2 months
# 28743     3 years
# 28744    3 months

# %%
import pandas as pd

# Assuming 'date_intake' and 'date_outcome' are your columns with date
# Convert them to datetime format
df['date_intake'] = pd.to_datetime(df['date_intake'])
df['date_outcome'] = pd.to_datetime(df['date_outcome'])

# Calculate the stay_length by subtracting intake_date from outcome_date
df['stay_length'] = (df['date_outcome'] - df['date_intake']).dt.days

# %%
df.head(50)
# Out:
#    Animal ID         date_intake      intake_type intake_condition  \
# 0    A664887 2013-10-10 13:48:00            Stray           Normal
# 1    A665496 2013-10-18 18:07:00            Stray           Normal
# 2    A664936 2013-10-11 11:20:00            Stray           Normal
# 3    A665398 2013-10-17 12:26:00  Owner Surrender           Normal
# 4    A665426 2013-10-17 16:53:00            Stray           Normal
# 5    A666091 2013-10-26 16:43:00            Stray           Normal
# 6    A665994 2013-10-25 17:41:00            Stray           Normal
# 7    A664857 2013-10-10 07:47:00            Stray           Normal
# 8    A664754 2013-10-08 16:46:00  Owner Surrender           Normal
# 9    A664446 2013-10-03 13:06:00            Stray          Injured
# 10   A665474 2013-10-18 13:19:00            Stray           Normal
# 11   A664571 2013-10-05 13:43:00  Owner Surrender           Normal
# 12   A664574 2013-10-05 13:43:00  Owner Surrender           Normal
# 13   A664322 2013-10-01 19:01:00            Stray           Normal
# 14   A663723 2013-10-09 12:11:00  Owner Surrender           Normal
# 15   A664544 2013-10-05 11:34:00            Stray           Normal
# 16   A664340 2013-10-02 10:51:00  Owner Surrender           Normal
# 17   A665550 2013-10-19 11:32:00            Stray           Normal
# 18   A665580 2013-10-19 15:20:00            Stray           Normal
# 19   A647165 2013-10-09 17:24:00  Owner Surrender           Normal
# 20   A665310 2013-10-16 12:00:00  Owner Surrender           Normal
# 21   A664186 2013-10-22 18:42:00  Owner Surrender           Normal
# 22   A666109 2013-10-27 11:09:00  Owner Surrender           Normal
# 23   A664442 2013-10-03 12:42:00            Stray           Normal
# 24   A664751 2013-10-08 16:46:00  Owner Surrender           Normal
# 25   A665070 2013-10-13 11:13:00            Stray           Normal
# 26   A665739 2013-10-22 11:11:00            Stray           Normal
# 27   A665928 2013-10-24 15:27:00  Owner Surrender             Sick
# 28   A665306 2013-10-16 11:42:00            Stray          Injured
# 29   A666090 2013-10-26 15:52:00            Stray           Normal
# 30   A665262 2013-10-15 17:52:00            Stray           Normal
# 31   A665424 2013-10-17 16:53:00            Stray           Normal
# 32   A664972 2013-10-11 18:04:00            Stray           Normal
# 33   A664708 2013-10-07 18:13:00            Stray           Normal
# 34   A665019 2013-10-12 14:00:00            Stray           Normal
# 35   A665394 2013-10-17 12:26:00  Owner Surrender           Normal
# 36   A665740 2013-10-22 11:11:00            Stray           Normal
# 37   A664661 2013-10-07 11:02:00            Stray           Normal
# 38   A664994 2013-10-12 11:52:00            Stray           Normal
# 39   A664505 2013-10-11 15:11:00  Owner Surrender           Normal
# 40   A663550 2013-10-22 13:36:00  Owner Surrender           Normal
# 41   A665661 2013-10-21 14:24:00            Stray           Normal
# 42   A664753 2013-10-08 16:46:00  Owner Surrender           Normal
# 43   A666088 2013-10-26 15:52:00            Stray           Normal
# 44   A665022 2013-10-12 14:14:00            Stray           Normal
# 45   A664749 2013-10-08 16:46:00  Owner Surrender           Normal
# 46   A665312 2013-10-16 12:00:00  Owner Surrender           Normal
# 47   A664503 2013-10-04 12:08:00            Stray           Normal
# 48   A664970 2013-10-11 18:16:00            Stray           Normal
# 49   A664515 2013-10-04 15:23:00  Owner Surrender           Normal
#
#        sex_intake age_intake                     breed               color  \
# 0   Intact Female    1 month    Domestic Shorthair Mix               Black
# 1   Neutered Male    3 years                    Bengal         Brown Tiger
# 2     Intact Male    1 month  Domestic Medium Hair Mix         Brown Tabby
# 3   Intact Female    1 month    Domestic Shorthair Mix          White/Blue
# 4     Intact Male    1 month    Domestic Shorthair Mix               Black
# 5     Intact Male    1 month  Domestic Medium Hair Mix         Black/White
# 6   Intact Female   3 months    Domestic Shorthair Mix              Calico
# 7     Intact Male   6 months    Domestic Shorthair Mix         Black/White
# 8     Intact Male   5 months    Domestic Shorthair Mix               Black
# 9     Intact Male    3 years    Domestic Shorthair Mix        Orange Tabby
# 10  Intact Female    1 month    Domestic Shorthair Mix               Black
# 11  Spayed Female    2 years    Domestic Shorthair Mix              Torbie
# 12    Intact Male   3 months    Domestic Shorthair Mix         Brown Tabby
# 13  Intact Female    3 weeks    Domestic Shorthair Mix              Tortie
# 14  Neutered Male   2 months    Domestic Shorthair Mix         Brown Tabby
# 15  Intact Female   6 months    Domestic Shorthair Mix         Brown Tabby
# 16  Intact Female    1 month    Domestic Shorthair Mix         Black/White
# 17    Intact Male   2 months    Domestic Shorthair Mix         Black/White
# 18    Intact Male    1 month    Domestic Shorthair Mix               Black
# 19  Spayed Female     1 year               Siamese Mix          Seal Point
# 20  Intact Female    1 month    Domestic Shorthair Mix              Tortie
# 21  Spayed Female   2 months    Domestic Shorthair Mix         Brown Tabby
# 22    Intact Male   2 months    Domestic Shorthair Mix  Orange Tabby/White
# 23    Intact Male    1 month    Domestic Shorthair Mix               Black
# 24  Intact Female    1 month    Domestic Shorthair Mix        Tortie/White
# 25  Intact Female    4 weeks    Domestic Shorthair Mix         Brown Tabby
# 26  Intact Female    1 month  Domestic Medium Hair Mix               Black
# 27  Intact Female    4 weeks    Domestic Shorthair Mix                Blue
# 28    Intact Male   4 months    Domestic Shorthair Mix         Black/White
# 29  Intact Female    3 years    Domestic Shorthair Mix        Orange Tabby
# 30    Intact Male    3 weeks    Domestic Shorthair Mix         Black/White
# 31  Intact Female    1 month    Domestic Shorthair Mix               Black
# 32    Intact Male    4 weeks               Siamese Mix          Lynx Point
# 33  Intact Female   3 months    Domestic Shorthair Mix   Brown Tabby/White
# 34  Spayed Female    8 years    Domestic Shorthair Mix              Torbie
# 35  Intact Female   9 months    Domestic Shorthair Mix   Brown Tabby/White
# 36  Intact Female    1 month  Domestic Medium Hair Mix               Black
# 37  Intact Female    1 month    Domestic Shorthair Mix         Black/White
# 38  Intact Female     1 year               Siamese Mix          Lynx Point
# 39  Spayed Female    4 years    Domestic Shorthair Mix  Orange Tabby/White
# 40  Neutered Male   3 months    Domestic Shorthair Mix         Cream Tabby
# 41  Intact Female    1 month    Domestic Shorthair Mix         White/Black
# 42  Intact Female   5 months    Domestic Shorthair Mix         Brown Tabby
# 43    Intact Male    1 month     Domestic Longhair Mix        Orange Tabby
# 44  Intact Female   2 months    Domestic Shorthair Mix              Calico
# 45    Intact Male    1 month    Domestic Shorthair Mix               Black
# 46  Intact Female    1 month    Domestic Shorthair Mix              Torbie
# 47    Intact Male   2 months    Domestic Shorthair Mix         Black/White
# 48    Intact Male    1 month    Domestic Shorthair Mix        Orange Tabby
# 49  Intact Female   3 months                  Manx Mix              Calico
#
#           date_outcome         dob outcome_type    sex_outcome age_outcome  \
# 0  2013-11-10 16:56:00  08/10/2013     Adoption  Spayed Female    3 months
# 1  2013-10-22 17:54:00  04/18/2010     Adoption  Neutered Male     3 years
# 2  2013-12-18 18:18:00  08/18/2013     Adoption  Neutered Male    4 months
# 3  2013-11-10 16:45:00  08/19/2013     Adoption  Spayed Female    2 months
# 4  2013-11-16 17:09:00  08/26/2013     Adoption  Neutered Male    2 months
# 5  2013-12-06 15:54:00  09/11/2013     Adoption  Neutered Male    2 months
# 6  2013-11-05 19:22:00  07/25/2013     Adoption  Spayed Female    3 months
# 7  2013-10-14 17:34:00  04/10/2013     Adoption  Neutered Male    6 months
# 8  2013-10-13 18:03:00  04/23/2013     Adoption  Neutered Male    5 months
# 9  2014-03-15 15:27:00  10/03/2010     Adoption  Neutered Male     3 years
# 10 2013-12-26 17:56:00  08/27/2013     Adoption  Spayed Female    3 months
# 11 2013-10-10 14:07:00  10/05/2011     Adoption  Spayed Female     2 years
# 12 2013-10-10 14:06:00  06/23/2013     Adoption  Neutered Male    3 months
# 13 2013-11-16 12:21:00  09/09/2013     Adoption  Spayed Female    2 months
# 14 2013-10-06 18:24:00  07/16/2013     Adoption  Neutered Male    2 months
# 15 2013-11-22 18:27:00  04/05/2013     Adoption  Spayed Female    7 months
# 16 2013-12-24 12:31:00  08/18/2013     Adoption  Spayed Female    4 months
# 17 2013-10-23 16:53:00  08/05/2013     Adoption  Neutered Male    2 months
# 18 2013-10-27 16:02:00  08/19/2013     Adoption  Neutered Male    2 months
# 19 2013-10-12 13:50:00  04/05/2012     Adoption  Spayed Female      1 year
# 20 2013-12-01 15:27:00  08/16/2013     Adoption  Spayed Female    3 months
# 21 2013-10-20 16:18:00  08/12/2013     Adoption  Spayed Female    2 months
# 22 2013-10-30 14:03:00  07/29/2013     Adoption  Neutered Male    3 months
# 23 2013-10-20 16:58:00  08/12/2013     Adoption  Neutered Male    2 months
# 24 2013-11-06 08:56:00  08/26/2013     Adoption  Spayed Female    2 months
# 25 2013-12-07 16:45:00  09/13/2013     Adoption  Spayed Female    2 months
# 26 2013-12-20 17:36:00  09/16/2013     Adoption  Spayed Female    3 months
# 27 2013-12-04 11:40:00  09/24/2013     Adoption  Spayed Female    2 months
# 28 2013-11-13 17:59:00  05/20/2013     Adoption  Neutered Male    5 months
# 29 2013-12-05 19:05:00  10/26/2010     Adoption  Spayed Female     3 years
# 30 2013-12-09 18:43:00  09/23/2013     Adoption  Neutered Male    2 months
# 31 2013-11-03 11:56:00  08/26/2013     Adoption  Intact Female    2 months
# 32 2013-11-22 15:48:00  09/11/2013     Adoption  Neutered Male    2 months
# 33 2013-10-12 13:54:00  06/22/2013     Adoption  Spayed Female    3 months
# 34 2013-12-05 15:30:00  10/12/2005     Adoption  Spayed Female     8 years
# 35 2013-10-25 18:31:00  12/17/2012     Adoption  Spayed Female   10 months
# 36 2013-12-20 17:39:00  09/16/2013     Adoption  Spayed Female    3 months
# 37 2013-10-13 17:04:00  08/07/2013     Adoption  Spayed Female    2 months
# 38 2013-12-01 18:05:00  10/12/2012     Adoption  Spayed Female      1 year
# 39 2013-12-24 13:16:00  10/04/2009     Adoption  Spayed Female     4 years
# 40 2013-10-13 17:43:00  07/11/2013     Adoption  Neutered Male    3 months
# 41 2013-12-26 09:31:00  08/22/2013     Adoption  Spayed Female    4 months
# 42 2013-10-13 18:02:00  04/23/2013     Adoption  Spayed Female    5 months
# 43 2013-12-02 18:07:00  08/26/2013     Adoption  Neutered Male    3 months
# 44 2013-10-16 18:29:00  08/05/2013     Adoption  Spayed Female    2 months
# 45 2013-11-04 16:39:00  08/26/2013     Adoption  Neutered Male    2 months
# 46 2013-11-25 17:42:00  08/16/2013     Adoption  Spayed Female    3 months
# 47 2013-10-10 18:17:00  07/20/2013     Adoption  Neutered Male    2 months
# 48 2013-10-16 18:41:00  08/14/2013     Adoption  Neutered Male    2 months
# 49 2013-10-13 18:52:00  06/19/2013     Adoption  Intact Female    3 months
#
#     stay_length
# 0            31
# 1             3
# 2            68
# 3            24
# 4            30
# 5            40
# 6            11
# 7             4
# 8             5
# 9           163
# 10           69
# 11            5
# 12            5
# 13           45
# 14           -3
# 15           48
# 16           83
# 17            4
# 18            8
# 19            2
# 20           46
# 21           -3
# 22            3
# 23           17
# 24           28
# 25           55
# 26           59
# 27           40
# 28           28
# 29           40
# 30           55
# 31           16
# 32           41
# 33            4
# 34           54
# 35            8
# 36           59
# 37            6
# 38           50
# 39           73
# 40           -9
# 41           65
# 42            5
# 43           37
# 44            4
# 45           26
# 46           40
# 47            6
# 48            5
# 49            9

# %%
#ALL COLORS TOGETGER SO YOU CAN HAVE AN IDEA OF WHY I CHOSE ONLY THE FIRST WORD
category_counts = df['color'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
# Extract the first word from the 'color' column
df['color'] = df['color'].str.split('/|\s').str[0].str.strip()

# Plot the distribution
category_counts = df['color'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(10, 6))

# Adding labels and title
plt.xlabel('Color Group')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
# Extract the first word from the 'color' column
df['color'] = df['color'].str.split('/|\s').str[0].str.strip()

# Count the frequencies
category_counts = df['color'].value_counts()

# Identify colors with frequency less than 1000
colors_to_group = category_counts[category_counts < 1000].index

# Group colors with frequency less than 1000 into 'Other'
df['color'] = df['color'].apply(lambda x: 'Other' if x in colors_to_group else x)

# Plot the distribution
category_counts = df['color'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(10, 6))

# Adding labels and title
plt.xlabel('Color Group')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
#NOW BREED
category_counts = df['breed'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
#we do the same as colors, only take the first string, in case of domestic, take the first two,
#because we have domestic long,short, and medium hair

# Extract the breed information
df['breed'] = df['breed'].apply(lambda x: ' '.join(x.split()[:2]) if x.startswith('Domestic') else x.split()[0])

# Count the frequencies
category_counts = df['breed'].value_counts()

# Plot the distribution
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(10, 6))

# Adding labels and title
plt.xlabel('Breed Group')
plt.ylabel('Frequency')
plt.title('Breed Data Distribution')

# Display the plot
plt.show()

# %%
# Extract the breed information
df['breed'] = df['breed'].apply(lambda x: ' '.join(x.split()[:2]) if x.startswith('Domestic') else x.split()[0])

# Count the frequencies
category_counts = df['breed'].value_counts()

# Identify breeds with frequency less than 1000
breeds_to_group = category_counts[category_counts < 1000].index

# Group breeds with frequency less than 1000 into 'Other'
df['breed'] = df['breed'].apply(lambda x: 'Other/Mix' if x in breeds_to_group else x)

# Plot the distribution
category_counts = df['breed'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(10, 6))

# Adding labels and title
plt.xlabel('Breed Group')
plt.ylabel('Frequency')
plt.title('Breed Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# # now that we are done with the two with the most unique values, we vizualize the rest, we obviously will drop unknown for sex

# %%
df = df[df['sex_intake'] != 'Unknown']
category_counts = df['sex_intake'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Sex Intake')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
# Drop rows where 'sex_outcome' is 'Unknown'
df = df[df['sex_outcome'] != 'Unknown']

# Plot the distribution after dropping 'Unknown'
category_counts = df['sex_outcome'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Sex Outcome')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# # see how it goes from intact f/m to spayed/neutered?

# %%
#cats might get spayed or not before being adopted
df = df[df['intake_type'] != 'Euthanasia Request']
category_counts = df['intake_type'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Intake Type')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
#THE OLDER THEY ARE, THE LESS LIKELY THEY GET ADOPTED, CATS THAT ENTERED OLD, MIGHT NOT LEAVE, WILL BECOME OLDER
#kittens too young might not a trend in age at outcome bc they are too little and delicate to leave
category_counts = df['age_outcome'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Age Outcome')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
category_counts = df['age_intake'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Age Intake')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
df.to_csv('clean_texas.csv', index=False)

# %%
# Import our libraries 

# Pandas and numpy for data wrangling
import pandas as pd
import numpy as np

# Seaborn / matplotlib for visualization 
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
# %matplotlib inline

# Helper function to split our data
from sklearn.model_selection import train_test_split

# Helper fuctions to evaluate our model.
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, roc_auc_score, f1_score

# Import our Decision Tree
from sklearn.tree import DecisionTreeClassifier 

# Import our Random Forest 
from sklearn.ensemble import RandomForestClassifier

# Import the trees from sklearn
from sklearn import tree

# Helper functions to visualize our trees
from sklearn.tree import plot_tree, export_text

#tree regression
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('dataset/df_only_numeric_value_nov_05.csv')
df.head()
# Out:
#   Primary_Color       Sex  Age Intake_Date Intake_Condition      Intake_Type  \
# 0     BRN TABBY    Spayed    6    12/19/18           NORMAL            STRAY
# 1     BRN TABBY    Spayed    9     10/4/19           NORMAL  OWNER SURRENDER
# 2     ORG TABBY  Neutered   12     6/24/17         ILL MILD            STRAY
# 3     BRN TABBY  Neutered    8     7/13/17           NORMAL            STRAY
# 4    GRAY TABBY    Spayed    8     5/10/17           NORMAL            STRAY
#
#    days_stayed  Primary_Color_encoded  Sex_encoded  Intake_Condition_encoded  \
# 0          799                      5            3                        13
# 1          760                      5            3                        13
# 2          685                     22            2                         7
# 3          666                      5            2                        13
# 4          661                     16            3                        13
#
#    Intake_Type_encoded
# 0                    3
# 1                    1
# 2                    3
# 3                    3
# 4                    3

# %%
# import pandas as pd

# def categorize_days(days_stayed):
#     if days_stayed <= 15:
#         return 0
#     elif days_stayed <= 45:
#         return 1
#     elif days_stayed <= 75:
#         return 2
#     elif days_stayed <= 105:
#         return 3
#     # Add more conditions as needed up to 1200 days
#     elif days_stayed <= 400:
#         # Calculate the month based on the provided conditions
#         return (days_stayed - 105) // 30 + 3
#     else:
#         # Handle cases beyond 1200 days if needed
#         return 100  # or any other value to indicate an outlier

# # Example usage:
# # Assuming df is your DataFrame and "days_stayed" is the column you want to categorize
# df['months_stayed'] = df['days_stayed'].apply(categorize_days)
# df.head(50)


import pandas as pd

def categorize_stay(days_stayed):
    if days_stayed <= 60:
        return 1
    else:
        return 0

# Example usage:
# Assuming df is your DataFrame and "days_stayed" is the column you want to categorize
df['stay'] = df['days_stayed'].apply(categorize_stay)
df.tail(50)
# Out:
#      Primary_Color       Sex  Age Intake_Date  Intake_Condition  \
# 2932      SNOWSHOE    Spayed    1     5/11/22  UNDER AGE/WEIGHT
# 2933       SEAL PT    Spayed    1     6/30/22  UNDER AGE/WEIGHT
# 2934        TORTIE    Spayed    2     7/11/22   INJURED  SEVERE
# 2935    CALICO TAB    Spayed    1    10/20/22            NORMAL
# 2936          GRAY    Spayed    1    10/26/22            NORMAL
# 2937    LI LYNX PT    Spayed    1    10/28/22  UNDER AGE/WEIGHT
# 2938          GRAY  Neutered    1     1/18/23            NORMAL
# 2939         BLACK  Neutered    0     3/31/23            NORMAL
# 2940          GRAY    Spayed    0     4/13/23        I/I REPORT
# 2941         BLACK    Spayed    0     4/20/23            NORMAL
# 2942         WHITE  Neutered    0     5/24/23          ILL MILD
# 2943         WHITE  Neutered    0     5/24/23          ILL MILD
# 2944       CHOC PT    Spayed    6     7/12/17        ILL SEVERE
# 2945        ORANGE      Male    6     12/2/17            NORMAL
# 2946          GRAY    Spayed    7     3/24/18            NORMAL
# 2947         WHITE    Spayed   12     7/27/18            NORMAL
# 2948         WHITE  Neutered   12     7/27/18            NORMAL
# 2949    GRAY TABBY  Neutered   16     2/16/19            NORMAL
# 2950         BLACK    Female    4     5/10/19  UNDER AGE/WEIGHT
# 2951         BLACK      Male    4     7/24/19  UNDER AGE/WEIGHT
# 2952    GRAY TABBY    Spayed    4     8/17/19            NORMAL
# 2953    GRAY TABBY    Spayed    4     1/30/20    BEHAVIOR  MILD
# 2954         WHITE  Neutered    4     2/25/20            NORMAL
# 2955     BRN TABBY    Spayed    4     3/17/20            NORMAL
# 2956         BLACK    Spayed    3     5/23/20            NORMAL
# 2957       LYNX PT    Spayed    3      6/3/20  UNDER AGE/WEIGHT
# 2958        S-T PT  Neutered    3    10/24/20            NORMAL
# 2959         BLACK  Neutered    3    11/13/20  UNDER AGE/WEIGHT
# 2960          GRAY    Spayed    4      4/8/21            NORMAL
# 2961    TORTIE DIL    Spayed    2     9/22/21            NORMAL
# 2962          GRAY    Spayed    2    12/10/21  UNDER AGE/WEIGHT
# 2963         BLACK  Neutered    1     5/21/22  UNDER AGE/WEIGHT
# 2964       LYNX PT    Spayed    1     6/11/22            NORMAL
# 2965     ORG TABBY  Neutered    1     6/18/22            NORMAL
# 2966        TORTIE    Spayed    1     6/24/22  UNDER AGE/WEIGHT
# 2967         BLACK  Neutered    1     8/13/22            NORMAL
# 2968          GRAY    Spayed    1    10/15/22            NORMAL
# 2969         WHITE    Spayed    1    11/19/22            NORMAL
# 2970         BLACK    Spayed    1     1/13/23            NORMAL
# 2971          GRAY  Neutered    0     4/21/23  UNDER AGE/WEIGHT
# 2972     BRN TABBY    Spayed    0     4/21/23  UNDER AGE/WEIGHT
# 2973         BROWN    Spayed    8      3/3/18            NORMAL
# 2974         BLACK      Male    4      6/2/19  UNDER AGE/WEIGHT
# 2975     BRN TABBY    Female    4     7/18/19  UNDER AGE/WEIGHT
# 2976     ORG TABBY  Neutered    2      8/9/21            NORMAL
# 2977        ORANGE    Spayed    2     8/21/21            NORMAL
# 2978     ORG TABBY  Neutered    2    12/18/21            NORMAL
# 2979     BRN TABBY    Spayed    1     5/18/22  UNDER AGE/WEIGHT
# 2980     BLK TABBY    Spayed    1    11/10/22            NORMAL
# 2981          GRAY  Neutered    0    12/21/22         FRACTIOUS
#
#           Intake_Type  days_stayed  Primary_Color_encoded  Sex_encoded  \
# 2932            STRAY            2                     26            3
# 2933            STRAY            2                     24            3
# 2934  OWNER SURRENDER            2                     29            3
# 2935            STRAY            2                     10            3
# 2936           RETURN            2                     15            3
# 2937            STRAY            2                     19            3
# 2938  OWNER SURRENDER            2                     15            2
# 2939            STRAY            2                      0            2
# 2940            STRAY            2                     15            3
# 2941            STRAY            2                      0            3
# 2942            STRAY            2                     32            2
# 2943            STRAY            2                     32            2
# 2944            STRAY            1                     11            3
# 2945  OWNER SURRENDER            1                     21            1
# 2946  OWNER SURRENDER            1                     15            3
# 2947  OWNER SURRENDER            1                     32            3
# 2948  OWNER SURRENDER            1                     32            2
# 2949  OWNER SURRENDER            1                     16            2
# 2950            STRAY            1                      0            0
# 2951            STRAY            1                      0            1
# 2952            STRAY            1                     16            3
# 2953           RETURN            1                     16            3
# 2954           RETURN            1                     32            2
# 2955           RETURN            1                      5            3
# 2956            STRAY            1                      0            3
# 2957            STRAY            1                     20            3
# 2958            STRAY            1                     23            2
# 2959            STRAY            1                      0            2
# 2960  OWNER SURRENDER            1                     15            3
# 2961            STRAY            1                     30            3
# 2962            STRAY            1                     15            3
# 2963            STRAY            1                      0            2
# 2964            STRAY            1                     20            3
# 2965            STRAY            1                     22            2
# 2966            STRAY            1                     29            3
# 2967            STRAY            1                      0            2
# 2968           RETURN            1                     15            3
# 2969            STRAY            1                     32            3
# 2970           RETURN            1                      0            3
# 2971            STRAY            1                     15            2
# 2972            STRAY            1                      5            3
# 2973  OWNER SURRENDER            0                      7            3
# 2974  OWNER SURRENDER            0                      0            1
# 2975            STRAY            0                      5            0
# 2976            STRAY            0                     22            2
# 2977            STRAY            0                     21            3
# 2978            STRAY            0                     22            2
# 2979            STRAY            0                      5            3
# 2980           RETURN            0                      2            3
# 2981            STRAY            0                     15            2
#
#       Intake_Condition_encoded  Intake_Type_encoded  stay
# 2932                        14                    3     1
# 2933                        14                    3     1
# 2934                        12                    1     1
# 2935                        13                    3     1
# 2936                        13                    2     1
# 2937                        14                    3     1
# 2938                        13                    1     1
# 2939                        13                    3     1
# 2940                         6                    3     1
# 2941                        13                    3     1
# 2942                         7                    3     1
# 2943                         7                    3     1
# 2944                         9                    3     1
# 2945                        13                    1     1
# 2946                        13                    1     1
# 2947                        13                    1     1
# 2948                        13                    1     1
# 2949                        13                    1     1
# 2950                        14                    3     1
# 2951                        14                    3     1
# 2952                        13                    3     1
# 2953                         1                    2     1
# 2954                        13                    2     1
# 2955                        13                    2     1
# 2956                        13                    3     1
# 2957                        14                    3     1
# 2958                        13                    3     1
# 2959                        14                    3     1
# 2960                        13                    1     1
# 2961                        13                    3     1
# 2962                        14                    3     1
# 2963                        14                    3     1
# 2964                        13                    3     1
# 2965                        13                    3     1
# 2966                        14                    3     1
# 2967                        13                    3     1
# 2968                        13                    2     1
# 2969                        13                    3     1
# 2970                        13                    2     1
# 2971                        14                    3     1
# 2972                        14                    3     1
# 2973                        13                    1     1
# 2974                        14                    1     1
# 2975                        14                    3     1
# 2976                        13                    3     1
# 2977                        13                    3     1
# 2978                        13                    3     1
# 2979                        14                    3     1
# 2980                        13                    2     1
# 2981                         5                    3     1

# %%
independent_variables = ['Primary_Color_encoded', 'Sex_encoded',  
                     'Intake_Condition_encoded', 'Intake_Type_encoded']

dependent_variable = 'stay'

# %%
# model = OneVsRestClassifier(DecisionTreeClassifier(max_depth=2))

# X = df[independent_variables]
# y = df[dependent_variable]

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# model.fit(X_train, y_train)

# y_pred = model.predict(X_test)

# # Eval Model
# accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
# print("Accuracy Score: %f" % accuracy)

# precision = precision_score(y_true=y_test, y_pred=y_pred, average='micro')
# print("Precision Score: %f" % precision)

# recall = recall_score(y_true=y_test, y_pred=y_pred, average='micro')
# print("Recall Score: %f" % recall)

# f1 = f1_score(y_true=y_test, y_pred=y_pred, average='micro')
# print('F1 Score: %f' % f1)

# # Calculate predicted probabilities
# y_pred_proba = model.predict_proba(X_test)

# # Keep only the proba for True
# y_pred_proba = y_pred_proba[:, 1]

# # Compute auc score
# auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
# print('AUC Score: %f' % auc)

# # Produce classification Report
# print(classification_report(y_test, y_pred))

# # Plot Tree
# # Note: Plotting trees for multi-class problems can be complex and may not provide clear visualizations
# # You may want to visualize individual trees if you're dealing with a smaller number of classes
# class_names = df[dependent_variable].unique()
# plot_tree(model.estimators_[0], feature_names=independent_variables, class_names=class_names, filled=True)

# %% [markdown]
# #RANDOM FOREST

# %%
# Initialize a Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=100)  # You can adjust the number of estimators as needed

X = df[independent_variables]
y = df[dependent_variable]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# Fit the model to the training data
model.fit(X_train, y_train)

# Now let's evaluate our model on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred, average='micro', zero_division=1)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred, average='micro')
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred, average='micro', zero_division=1)
print('F1 Score: %f' % f1)


# Calculate predicted probabilities
y_pred_proba = model.predict_proba(X_test)

# Produce classification Report
print(classification_report(y_test, y_pred))

# Calculate ROC AUC score for each class separately in multiclass classification
roc_auc_scores = []
unique_classes = np.unique(y_test)
for i in unique_classes:
    # Check if there is more than one class
    if len(unique_classes) > 1 and len(model.classes_) > 1:
        if i in model.classes_:
            # Get the column index corresponding to the current class
            col_idx = np.where(model.classes_ == i)[0][0]
            roc_auc_i = roc_auc_score(y_true=(y_test == i), y_score=y_pred_proba[:, col_idx], multi_class='ovr')
            roc_auc_scores.append(roc_auc_i)
        else:
            print(f"Skipping ROC AUC calculation for class {i} as it is not present in the model.")
    else:
        print(f"Skipping ROC AUC calculation for class {i} due to only one class present.")

# Print or use the ROC AUC scores as needed
for i, roc_auc_i in zip(unique_classes, roc_auc_scores):
    print(f'Class {i} ROC AUC Score: {roc_auc_i}')
# Out:
# Accuracy Score: 0.643216
# Precision Score: 0.643216
# Recall Score: 0.643216
# F1 Score: 0.643216
#               precision    recall  f1-score   support
#
#            0       0.48      0.14      0.21       210
#            1       0.66      0.92      0.77       387
#
#     accuracy                           0.64       597
#    macro avg       0.57      0.53      0.49       597
# weighted avg       0.60      0.64      0.57       597
#
# Class 0 ROC AUC Score: 0.5535929617324966
# Class 1 ROC AUC Score: 0.5535929617324966

# %%
# Now lets look at our feature importances
feature_imp = pd.Series(model.feature_importances_,index=independent_variables).sort_values(ascending=False)
feature_imp
# Out:
# Primary_Color_encoded       0.443222
# Intake_Condition_encoded    0.301204
# Sex_encoded                 0.144956
# Intake_Type_encoded         0.110618
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    # Add more hyperparameters to tune
}

grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best hyperparameters to train the model
best_model = RandomForestClassifier(**best_params)
best_model.fit(X_train, y_train)
# Out:
# Best Hyperparameters: {'max_depth': 10, 'n_estimators': 50}
# RandomForestClassifier(max_depth=10, n_estimators=50)

# %%
# Initialize an empty Random Forest model
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
X = df[independent_variables]
y = df[dependent_variable]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# Fit the model to the training data
model.fit(X_train, y_train)

# Now let's evaluate our model on the test set
y_pred = model.predict(X_test)

model.fit(X_train, y_train)

# Now lets evaluate our model
y_pred = model.predict(X_test)


## Eval Model 
accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred)
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred)
print('F1 Score: %f' % f1)

# Calculate predicted probabilities
y_pred_proba = model.predict_proba(X_test)

# # Keep only the proba for True
y_pred_proba = y_pred_proba[:,1]

# Compute auc score
auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
print('AUC Score: %f' % auc)


# Produce classification Report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.646566
# Precision Score: 0.662963
# Recall Score: 0.925065
# F1 Score: 0.772384
# AUC Score: 0.549256
#               precision    recall  f1-score   support
#
#            0       0.49      0.13      0.21       210
#            1       0.66      0.93      0.77       387
#
#     accuracy                           0.65       597
#    macro avg       0.58      0.53      0.49       597
# weighted avg       0.60      0.65      0.57       597

# %%
feature_importances = best_model.feature_importances_
feature_importances
# Out:
# array([0.41709287, 0.17389833, 0.27680123, 0.13220757])

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Extract one decision tree from the random forest (e.g., the first tree)
one_tree = model.estimators_[0]

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(one_tree, feature_names=independent_variables, class_names=class_names, filled=True)
plt.show()

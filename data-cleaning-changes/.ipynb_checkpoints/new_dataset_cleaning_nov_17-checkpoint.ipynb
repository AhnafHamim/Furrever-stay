# %%
# Our data management libraries
import pandas as pd
import numpy as np

# A basic visualization library
import matplotlib.pyplot as plt

# A great visualization library
import seaborn as sns

# Very important, this will make your charts appear in your notebook instead of in a new window.
# %matplotlib inline
from datetime import datetime


# Seaborn / matplotlib for visualization 
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
# %matplotlib inline

# Helper function to split our data
from sklearn.model_selection import train_test_split, GridSearchCV

# Helper fuctions to evaluate our model.
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, roc_auc_score, f1_score

# Import our Decision Tree
from sklearn.tree import DecisionTreeClassifier 

# Import our Random Forest 
from sklearn.ensemble import RandomForestClassifier

# Import the trees from sklearn
from sklearn import tree

# Helper functions to visualize our trees
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree, export_text
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score

# lebel encoder
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../dataset/Animal_Shelter_Intake_and_Outcome.csv')
df.head()
# Out:
#         Name Type               Breed            Color       Sex   Size  \
# 0    CUPCAKE  DOG  MALTESE/POODLE TOY            WHITE    Spayed    TOY
# 1        NaN  CAT         DOMESTIC SH            BLACK   Unknown  KITTN
# 2  SYLVESTER  CAT         DOMESTIC LH      BLACK/WHITE  Neutered  SMALL
# 3        NaN  CAT         DOMESTIC SH        BRN TABBY      Male  KITTN
# 4      *TESS  CAT         DOMESTIC SH  ORG TABBY/WHITE    Spayed  KITTN
#
#   Date Of Birth Impound Number Kennel Number Animal ID  ...    Intake Subtype  \
# 0    10/06/2014     K23-045263          DA04   A328255  ...             FIELD
# 1           NaN     K23-046275     RECEIVING   A420799  ...  OVER THE COUNTER
# 2    09/29/2013     K23-046271          CS05   A420773  ...  OVER THE COUNTER
# 3    08/15/2023     K23-046281          CI01   A420810  ...  OVER THE COUNTER
# 4    05/07/2023     K23-044867         LOBBY   A417889  ...  OVER THE COUNTER
#
#       Outcome Type         Outcome Subtype Intake Condition Outcome Condition  \
# 0         ADOPTION                SCAS WEB          UNKNOWN           PENDING
# 1         TRANSFER              PETLUMA PP          UNKNOWN           HEALTHY
# 2  RETURN TO OWNER  OVER THE COUNTER_MCHIP          HEALTHY           HEALTHY
# 3         TRANSFER                    HSSC          UNKNOWN   TREATABLE/REHAB
# 4         ADOPTION                  WALKIN          UNKNOWN           HEALTHY
#
#   Intake Jurisdiction Outcome Jurisdiction Outcome Zip Code  \
# 0          SANTA ROSA               COUNTY          95441.0
# 1              COUNTY            *PETALUMA          94952.0
# 2              COUNTY        OUT OF COUNTY          94901.0
# 3              COUNTY               COUNTY          95407.0
# 4              COUNTY           SANTA ROSA          95404.0
#
#                           Location Count
# 0      95441(38.70854, -122.90737)     1
# 1       94952(38.237, -122.640695)     1
# 2  94901(37.9702346, -122.5260879)     1
# 3  95407(38.4127094, -122.7412153)     1
# 4        95404(38.44511, -122.708)     1
#
# [5 rows x 24 columns]

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicated().sum())
# Out:
# 0

# %%
# List of columns you want to drop
columns_to_drop = ['Name', 'Impound Number', 'Kennel Number',
                   'Intake Subtype','Outcome Subtype','Intake Jurisdiction',
                   'Outcome Jurisdiction','Outcome Zip Code','Location','Count']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#   Type               Breed            Color       Sex   Size Date Of Birth  \
# 0  DOG  MALTESE/POODLE TOY            WHITE    Spayed    TOY    10/06/2014
# 1  CAT         DOMESTIC SH            BLACK   Unknown  KITTN           NaN
# 2  CAT         DOMESTIC LH      BLACK/WHITE  Neutered  SMALL    09/29/2013
# 3  CAT         DOMESTIC SH        BRN TABBY      Male  KITTN    08/15/2023
# 4  CAT         DOMESTIC SH  ORG TABBY/WHITE    Spayed  KITTN    05/07/2023
#
#   Animal ID Intake Date Outcome Date  Days in Shelter Intake Type  \
# 0   A328255  07/05/2023   08/08/2023               34       STRAY
# 1   A420799  09/30/2023   09/30/2023                0       STRAY
# 2   A420773  09/29/2023   09/30/2023                1       STRAY
# 3   A420810  09/30/2023   09/30/2023                0       STRAY
# 4   A417889  05/30/2023   08/08/2023               70       STRAY
#
#       Outcome Type Intake Condition Outcome Condition
# 0         ADOPTION          UNKNOWN           PENDING
# 1         TRANSFER          UNKNOWN           HEALTHY
# 2  RETURN TO OWNER          HEALTHY           HEALTHY
# 3         TRANSFER          UNKNOWN   TREATABLE/REHAB
# 4         ADOPTION          UNKNOWN           HEALTHY

# %%
df = df[df['Sex'] != 'Unknown']

# %%
#only keep cats
df = df[df['Type'] == 'CAT']
df = df[(df['Outcome Type'] == 'ADOPTION') | (df['Outcome Type'] == 'RETURN TO OWNER')]
df.head()
# Out:
#    Type        Breed            Color       Sex   Size Date Of Birth  \
# 2   CAT  DOMESTIC LH      BLACK/WHITE  Neutered  SMALL    09/29/2013
# 4   CAT  DOMESTIC SH  ORG TABBY/WHITE    Spayed  KITTN    05/07/2023
# 15  CAT  DOMESTIC SH            BLACK  Neutered  KITTN    05/22/2023
# 17  CAT  SIAMESE/MIX          LYNX PT  Neutered  KITTN    05/13/2023
# 20  CAT  DOMESTIC SH            BLACK  Neutered  KITTN    07/13/2023
#
#    Animal ID Intake Date Outcome Date  Days in Shelter      Intake Type  \
# 2    A420773  09/29/2023   09/30/2023                1            STRAY
# 4    A417889  05/30/2023   08/08/2023               70            STRAY
# 15   A418221  06/13/2023   08/08/2023               56            STRAY
# 17   A420264  09/12/2023   09/30/2023               18  OWNER SURRENDER
# 20   A419416  08/01/2023   09/30/2023               60            STRAY
#
#        Outcome Type Intake Condition Outcome Condition
# 2   RETURN TO OWNER          HEALTHY           HEALTHY
# 4          ADOPTION          UNKNOWN           HEALTHY
# 15         ADOPTION          UNKNOWN           HEALTHY
# 17         ADOPTION          HEALTHY           HEALTHY
# 20         ADOPTION          UNKNOWN           HEALTHY

# %%
# Convert 'Date of Birth' to datetime format
df['Date Of Birth'] = pd.to_datetime(df['Date Of Birth'])

# Calculate age based on the current date
current_date = datetime.now()
df['Age'] = (current_date - df['Date Of Birth']).astype('<m8[Y]')
df.head(50)
# Out:
#     Type                   Breed                  Color       Sex   Size  \
# 2    CAT             DOMESTIC LH            BLACK/WHITE  Neutered  SMALL
# 4    CAT             DOMESTIC SH        ORG TABBY/WHITE    Spayed  KITTN
# 15   CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 17   CAT             SIAMESE/MIX                LYNX PT  Neutered  KITTN
# 20   CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 22   CAT             DOMESTIC SH        BRN TABBY/WHITE    Spayed  KITTN
# 24   CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 25   CAT             DOMESTIC SH             GRAY TABBY  Neutered  KITTN
# 54   CAT             DOMESTIC SH  GRAY TABBY/BLUE CREAM    Spayed  KITTN
# 56   CAT             DOMESTIC SH                  BLACK    Spayed  KITTN
# 59   CAT             DOMESTIC MH                  BLACK  Neutered  SMALL
# 60   CAT             DOMESTIC MH                   GRAY  Neutered  KITTN
# 65   CAT             DOMESTIC SH                  BLACK  Neutered  SMALL
# 67   CAT             DOMESTIC SH                  BLACK  Neutered  SMALL
# 81   CAT             DOMESTIC LH            BLACK/WHITE  Neutered  KITTN
# 82   CAT             DOMESTIC SH            BLACK/WHITE    Spayed  KITTN
# 96   CAT  ABYSSINIAN/DOMESTIC SH       AGOUTI/BRN TABBY  Neutered  SMALL
# 98   CAT             DOMESTIC SH            WHITE/BLACK  Neutered  SMALL
# 106  CAT             DOMESTIC SH                   GRAY  Neutered  SMALL
# 108  CAT             DOMESTIC SH       BRN TABBY/TORTIE    Spayed  KITTN
# 110  CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 111  CAT             DOMESTIC SH             GRAY TABBY  Neutered  KITTN
# 114  CAT             DOMESTIC LH              BRN TABBY  Neutered  KITTN
# 120  CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 136  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 138  CAT             DOMESTIC MH                 TORTIE    Spayed  SMALL
# 145  CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 147  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  KITTN
# 149  CAT             DOMESTIC SH      SLVR TABBY/TORTIE    Spayed  SMALL
# 154  CAT             DOMESTIC MH             GRAY/WHITE    Spayed  SMALL
# 158  CAT             DOMESTIC SH           TORTIE/WHITE    Spayed  SMALL
# 162  CAT             DOMESTIC SH                  BLACK    Spayed  SMALL
# 164  CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 170  CAT             DOMESTIC SH                   GRAY    Spayed  KITTN
# 174  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  KITTN
# 178  CAT             DOMESTIC SH                  BLACK    Spayed  KITTN
# 183  CAT             DOMESTIC SH            BLACK/WHITE    Spayed  KITTN
# 186  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 195  CAT             DOMESTIC SH           TORTIE/WHITE    Spayed  KITTN
# 197  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  SMALL
# 200  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 207  CAT             DOMESTIC MH             WHITE/GRAY    Spayed  SMALL
# 210  CAT             DOMESTIC SH              BRN TABBY  Neutered  KITTN
# 212  CAT             DOMESTIC SH        BRN TABBY/WHITE    Spayed  SMALL
# 215  CAT             DOMESTIC SH              BRN TABBY    Spayed  KITTN
# 216  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  SMALL
# 220  CAT             DOMESTIC SH              BRN TABBY  Neutered  KITTN
# 229  CAT             DOMESTIC SH             GRAY TABBY    Spayed  SMALL
# 230  CAT             DOMESTIC SH           ORANGE/WHITE  Neutered  SMALL
# 233  CAT             DOMESTIC MH            WHITE/BLACK    Spayed  KITTN
#
#     Date Of Birth Animal ID Intake Date Outcome Date  Days in Shelter  \
# 2      2013-09-29   A420773  09/29/2023   09/30/2023                1
# 4      2023-05-07   A417889  05/30/2023   08/08/2023               70
# 15     2023-05-22   A418221  06/13/2023   08/08/2023               56
# 17     2023-05-13   A420264  09/12/2023   09/30/2023               18
# 20     2023-07-13   A419416  08/01/2023   09/30/2023               60
# 22     2023-07-13   A419414  09/12/2023   09/30/2023               18
# 24     2021-08-30   A419755  08/17/2023   09/30/2023               44
# 25     2023-07-07   A420237  09/07/2023   09/30/2023               23
# 54     2023-07-05   A420169  09/05/2023   10/03/2023               28
# 56     2023-03-03   A418629  06/27/2023   08/11/2023               45
# 59     2020-06-22   A418390  06/17/2023   08/11/2023               55
# 60     2023-05-08   A418894  07/08/2023   08/11/2023               34
# 65     2010-04-01   A419564  08/10/2023   08/11/2023                1
# 67     2022-06-13   A419570  08/11/2023   08/11/2023                0
# 81     2023-05-26   A420042  08/30/2023   10/03/2023               34
# 82     2023-06-26   A418627  06/27/2023   10/03/2023               98
# 96     2021-07-19   A418471  06/21/2023   08/15/2023               55
# 98     2023-03-06   A419845  08/22/2023   10/04/2023               43
# 106    2016-09-04   A344650  10/28/2016   11/17/2016               20
# 108    2022-05-17   A412853  08/13/2022   09/10/2022               28
# 110    2022-06-30   A418736  06/30/2023   08/15/2023               46
# 111    2023-04-03   A419450  08/03/2023   08/15/2023               12
# 114    2023-04-29   A418239  06/13/2023   07/11/2023               28
# 120           NaT   A420268  09/09/2023   10/05/2023               26
# 136    2023-06-26   A418625  06/27/2023   10/06/2023              101
# 138    2023-03-25   A420157  09/05/2023   10/06/2023               31
# 145    2023-07-13   A420379  09/13/2023   10/06/2023               23
# 147    2023-08-01   A420467  09/16/2023   10/06/2023               20
# 149    2017-04-01   A420962  10/06/2023   10/06/2023                0
# 154    2023-04-05   A420158  09/05/2023   10/07/2023               32
# 158    2021-09-10   A420297  09/10/2023   10/07/2023               27
# 162    2023-03-08   A420252  09/08/2023   10/07/2023               29
# 164    2023-05-30   A420131  09/02/2023   09/14/2023               12
# 170    2023-05-31   A418863  07/07/2023   08/17/2023               41
# 174    2023-06-17   A420129  09/02/2023   09/14/2023               12
# 178    2014-07-13   A314911  12/14/2014   01/16/2015               33
# 183    2017-05-26   A355971  07/26/2017   08/04/2017                9
# 186    2023-05-04   A416917  08/11/2023   08/12/2023                1
# 195    2017-05-11   A355986  07/26/2017   08/04/2017                9
# 197    2023-02-22   A419227  07/22/2023   08/18/2023               27
# 200    2023-05-04   A416917  04/22/2023   08/04/2023              104
# 207    2011-12-16   A330945  12/16/2015   12/26/2015               10
# 210    2023-03-15   A418813  07/05/2023   08/19/2023               45
# 212    2015-08-11   A417951  06/01/2023   08/11/2023               71
# 215    2023-05-31   A418812  07/05/2023   08/19/2023               45
# 216    2023-04-28   A419372  07/28/2023   08/19/2023               22
# 220    2023-04-15   A419040  07/14/2023   08/19/2023               36
# 229           NaT   A419849  08/22/2023   08/22/2023                0
# 230    2018-02-22   A419520  08/08/2023   08/22/2023               14
# 233    2023-04-16   A418375  06/16/2023   08/22/2023               67
#
#          Intake Type     Outcome Type Intake Condition Outcome Condition   Age
# 2              STRAY  RETURN TO OWNER          HEALTHY           HEALTHY  10.0
# 4              STRAY         ADOPTION          UNKNOWN           HEALTHY   0.0
# 15             STRAY         ADOPTION          UNKNOWN           HEALTHY   0.0
# 17   OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY   0.0
# 20             STRAY         ADOPTION          UNKNOWN           HEALTHY   0.0
# 22             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 24             STRAY         ADOPTION          HEALTHY           HEALTHY   2.0
# 25             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 54             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 56             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 59             STRAY         ADOPTION          HEALTHY           HEALTHY   3.0
# 60             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 65        CONFISCATE  RETURN TO OWNER          UNKNOWN           PENDING  13.0
# 67        CONFISCATE  RETURN TO OWNER          UNKNOWN           PENDING   1.0
# 81             STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 82             STRAY         ADOPTION          UNKNOWN           HEALTHY   0.0
# 96             STRAY         ADOPTION          HEALTHY           HEALTHY   2.0
# 98             STRAY         ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB   0.0
# 106            STRAY         ADOPTION          HEALTHY           HEALTHY   7.0
# 108            STRAY         ADOPTION          HEALTHY           HEALTHY   1.0
# 110            STRAY         ADOPTION          HEALTHY           HEALTHY   1.0
# 111            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 114            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 120       QUARANTINE  RETURN TO OWNER          UNKNOWN              DEAD   NaN
# 136            STRAY         ADOPTION          UNKNOWN           HEALTHY   0.0
# 138  OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY   0.0
# 145            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 147            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 149            STRAY  RETURN TO OWNER          UNKNOWN           PENDING   6.0
# 154  OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY   0.0
# 158       CONFISCATE         ADOPTION          HEALTHY           HEALTHY   2.0
# 162            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 164            STRAY         ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB   0.0
# 170            STRAY         ADOPTION  TREATABLE/REHAB           HEALTHY   0.0
# 174            STRAY         ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB   0.0
# 178            STRAY         ADOPTION          HEALTHY           HEALTHY   9.0
# 183  OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY   6.0
# 186  ADOPTION RETURN         ADOPTION          HEALTHY           HEALTHY   0.0
# 195  OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY   6.0
# 197            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 200        BORN HERE         ADOPTION          UNKNOWN           HEALTHY   0.0
# 207  OWNER SURRENDER         ADOPTION          HEALTHY           HEALTHY  11.0
# 210            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 212            STRAY         ADOPTION          HEALTHY           HEALTHY   8.0
# 215            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 216            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 220            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0
# 229            STRAY  RETURN TO OWNER          UNKNOWN           PENDING   NaN
# 230            STRAY  RETURN TO OWNER          UNKNOWN           PENDING   5.0
# 233            STRAY         ADOPTION          HEALTHY           HEALTHY   0.0

# %%
print(df.isnull().sum())
# Out:
# Type                   0
# Breed                  0
# Color                  0
# Sex                    0
# Size                   0
# Date Of Birth        493
# Animal ID              0
# Intake Date            0
# Outcome Date           0
# Days in Shelter        0
# Intake Type            0
# Outcome Type           0
# Intake Condition       0
# Outcome Condition      9
# Age                  493
# dtype: int64

# %%
# Age is a quantitative data so we will fill out the null values of it with mean value
# df['Age']= df['Age'].fillna(df['Age'].mean()).astype(int)
df['Age']= df['Age'].fillna(-1).astype(int)
df['Age'].isna().sum()
# Out:
# 0

# %%
df['Age'].min()
# Out:
# -1

# %%
# rechecking for null values
print(df.isnull().sum())
# Out:
# Type                   0
# Breed                  0
# Color                  0
# Sex                    0
# Size                   0
# Date Of Birth        493
# Animal ID              0
# Intake Date            0
# Outcome Date           0
# Days in Shelter        0
# Intake Type            0
# Outcome Type           0
# Intake Condition       0
# Outcome Condition      9
# Age                    0
# dtype: int64

# %%
df = df.dropna(subset=['Outcome Condition'])

# %%
# rechecking for null values
print(df.isnull().sum())
# Out:
# Type                   0
# Breed                  0
# Color                  0
# Sex                    0
# Size                   0
# Date Of Birth        490
# Animal ID              0
# Intake Date            0
# Outcome Date           0
# Days in Shelter        0
# Intake Type            0
# Outcome Type           0
# Intake Condition       0
# Outcome Condition      0
# Age                    0
# dtype: int64

# %%
df = df.drop(columns=['Date Of Birth'])
df.head(50)
# Out:
#     Type                   Breed                  Color       Sex   Size  \
# 2    CAT             DOMESTIC LH            BLACK/WHITE  Neutered  SMALL
# 4    CAT             DOMESTIC SH        ORG TABBY/WHITE    Spayed  KITTN
# 15   CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 17   CAT             SIAMESE/MIX                LYNX PT  Neutered  KITTN
# 20   CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 22   CAT             DOMESTIC SH        BRN TABBY/WHITE    Spayed  KITTN
# 24   CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 25   CAT             DOMESTIC SH             GRAY TABBY  Neutered  KITTN
# 54   CAT             DOMESTIC SH  GRAY TABBY/BLUE CREAM    Spayed  KITTN
# 56   CAT             DOMESTIC SH                  BLACK    Spayed  KITTN
# 59   CAT             DOMESTIC MH                  BLACK  Neutered  SMALL
# 60   CAT             DOMESTIC MH                   GRAY  Neutered  KITTN
# 65   CAT             DOMESTIC SH                  BLACK  Neutered  SMALL
# 67   CAT             DOMESTIC SH                  BLACK  Neutered  SMALL
# 81   CAT             DOMESTIC LH            BLACK/WHITE  Neutered  KITTN
# 82   CAT             DOMESTIC SH            BLACK/WHITE    Spayed  KITTN
# 96   CAT  ABYSSINIAN/DOMESTIC SH       AGOUTI/BRN TABBY  Neutered  SMALL
# 98   CAT             DOMESTIC SH            WHITE/BLACK  Neutered  SMALL
# 106  CAT             DOMESTIC SH                   GRAY  Neutered  SMALL
# 108  CAT             DOMESTIC SH       BRN TABBY/TORTIE    Spayed  KITTN
# 110  CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 111  CAT             DOMESTIC SH             GRAY TABBY  Neutered  KITTN
# 114  CAT             DOMESTIC LH              BRN TABBY  Neutered  KITTN
# 120  CAT             DOMESTIC MH        BRN TABBY/WHITE  Neutered  SMALL
# 136  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 138  CAT             DOMESTIC MH                 TORTIE    Spayed  SMALL
# 145  CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 147  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  KITTN
# 149  CAT             DOMESTIC SH      SLVR TABBY/TORTIE    Spayed  SMALL
# 154  CAT             DOMESTIC MH             GRAY/WHITE    Spayed  SMALL
# 158  CAT             DOMESTIC SH           TORTIE/WHITE    Spayed  SMALL
# 162  CAT             DOMESTIC SH                  BLACK    Spayed  SMALL
# 164  CAT             DOMESTIC SH                  BLACK  Neutered  KITTN
# 170  CAT             DOMESTIC SH                   GRAY    Spayed  KITTN
# 174  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  KITTN
# 178  CAT             DOMESTIC SH                  BLACK    Spayed  KITTN
# 183  CAT             DOMESTIC SH            BLACK/WHITE    Spayed  KITTN
# 186  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 195  CAT             DOMESTIC SH           TORTIE/WHITE    Spayed  KITTN
# 197  CAT             DOMESTIC SH            WHITE/BLACK    Spayed  SMALL
# 200  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  KITTN
# 207  CAT             DOMESTIC MH             WHITE/GRAY    Spayed  SMALL
# 210  CAT             DOMESTIC SH              BRN TABBY  Neutered  KITTN
# 212  CAT             DOMESTIC SH        BRN TABBY/WHITE    Spayed  SMALL
# 215  CAT             DOMESTIC SH              BRN TABBY    Spayed  KITTN
# 216  CAT             DOMESTIC SH            BLACK/WHITE  Neutered  SMALL
# 220  CAT             DOMESTIC SH              BRN TABBY  Neutered  KITTN
# 229  CAT             DOMESTIC SH             GRAY TABBY    Spayed  SMALL
# 230  CAT             DOMESTIC SH           ORANGE/WHITE  Neutered  SMALL
# 233  CAT             DOMESTIC MH            WHITE/BLACK    Spayed  KITTN
#
#     Animal ID Intake Date Outcome Date  Days in Shelter      Intake Type  \
# 2     A420773  09/29/2023   09/30/2023                1            STRAY
# 4     A417889  05/30/2023   08/08/2023               70            STRAY
# 15    A418221  06/13/2023   08/08/2023               56            STRAY
# 17    A420264  09/12/2023   09/30/2023               18  OWNER SURRENDER
# 20    A419416  08/01/2023   09/30/2023               60            STRAY
# 22    A419414  09/12/2023   09/30/2023               18            STRAY
# 24    A419755  08/17/2023   09/30/2023               44            STRAY
# 25    A420237  09/07/2023   09/30/2023               23            STRAY
# 54    A420169  09/05/2023   10/03/2023               28            STRAY
# 56    A418629  06/27/2023   08/11/2023               45            STRAY
# 59    A418390  06/17/2023   08/11/2023               55            STRAY
# 60    A418894  07/08/2023   08/11/2023               34            STRAY
# 65    A419564  08/10/2023   08/11/2023                1       CONFISCATE
# 67    A419570  08/11/2023   08/11/2023                0       CONFISCATE
# 81    A420042  08/30/2023   10/03/2023               34            STRAY
# 82    A418627  06/27/2023   10/03/2023               98            STRAY
# 96    A418471  06/21/2023   08/15/2023               55            STRAY
# 98    A419845  08/22/2023   10/04/2023               43            STRAY
# 106   A344650  10/28/2016   11/17/2016               20            STRAY
# 108   A412853  08/13/2022   09/10/2022               28            STRAY
# 110   A418736  06/30/2023   08/15/2023               46            STRAY
# 111   A419450  08/03/2023   08/15/2023               12            STRAY
# 114   A418239  06/13/2023   07/11/2023               28            STRAY
# 120   A420268  09/09/2023   10/05/2023               26       QUARANTINE
# 136   A418625  06/27/2023   10/06/2023              101            STRAY
# 138   A420157  09/05/2023   10/06/2023               31  OWNER SURRENDER
# 145   A420379  09/13/2023   10/06/2023               23            STRAY
# 147   A420467  09/16/2023   10/06/2023               20            STRAY
# 149   A420962  10/06/2023   10/06/2023                0            STRAY
# 154   A420158  09/05/2023   10/07/2023               32  OWNER SURRENDER
# 158   A420297  09/10/2023   10/07/2023               27       CONFISCATE
# 162   A420252  09/08/2023   10/07/2023               29            STRAY
# 164   A420131  09/02/2023   09/14/2023               12            STRAY
# 170   A418863  07/07/2023   08/17/2023               41            STRAY
# 174   A420129  09/02/2023   09/14/2023               12            STRAY
# 178   A314911  12/14/2014   01/16/2015               33            STRAY
# 183   A355971  07/26/2017   08/04/2017                9  OWNER SURRENDER
# 186   A416917  08/11/2023   08/12/2023                1  ADOPTION RETURN
# 195   A355986  07/26/2017   08/04/2017                9  OWNER SURRENDER
# 197   A419227  07/22/2023   08/18/2023               27            STRAY
# 200   A416917  04/22/2023   08/04/2023              104        BORN HERE
# 207   A330945  12/16/2015   12/26/2015               10  OWNER SURRENDER
# 210   A418813  07/05/2023   08/19/2023               45            STRAY
# 212   A417951  06/01/2023   08/11/2023               71            STRAY
# 215   A418812  07/05/2023   08/19/2023               45            STRAY
# 216   A419372  07/28/2023   08/19/2023               22            STRAY
# 220   A419040  07/14/2023   08/19/2023               36            STRAY
# 229   A419849  08/22/2023   08/22/2023                0            STRAY
# 230   A419520  08/08/2023   08/22/2023               14            STRAY
# 233   A418375  06/16/2023   08/22/2023               67            STRAY
#
#         Outcome Type Intake Condition Outcome Condition  Age
# 2    RETURN TO OWNER          HEALTHY           HEALTHY   10
# 4           ADOPTION          UNKNOWN           HEALTHY    0
# 15          ADOPTION          UNKNOWN           HEALTHY    0
# 17          ADOPTION          HEALTHY           HEALTHY    0
# 20          ADOPTION          UNKNOWN           HEALTHY    0
# 22          ADOPTION          HEALTHY           HEALTHY    0
# 24          ADOPTION          HEALTHY           HEALTHY    2
# 25          ADOPTION          HEALTHY           HEALTHY    0
# 54          ADOPTION          HEALTHY           HEALTHY    0
# 56          ADOPTION          HEALTHY           HEALTHY    0
# 59          ADOPTION          HEALTHY           HEALTHY    3
# 60          ADOPTION          HEALTHY           HEALTHY    0
# 65   RETURN TO OWNER          UNKNOWN           PENDING   13
# 67   RETURN TO OWNER          UNKNOWN           PENDING    1
# 81          ADOPTION          HEALTHY           HEALTHY    0
# 82          ADOPTION          UNKNOWN           HEALTHY    0
# 96          ADOPTION          HEALTHY           HEALTHY    2
# 98          ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB    0
# 106         ADOPTION          HEALTHY           HEALTHY    7
# 108         ADOPTION          HEALTHY           HEALTHY    1
# 110         ADOPTION          HEALTHY           HEALTHY    1
# 111         ADOPTION          HEALTHY           HEALTHY    0
# 114         ADOPTION          HEALTHY           HEALTHY    0
# 120  RETURN TO OWNER          UNKNOWN              DEAD   -1
# 136         ADOPTION          UNKNOWN           HEALTHY    0
# 138         ADOPTION          HEALTHY           HEALTHY    0
# 145         ADOPTION          HEALTHY           HEALTHY    0
# 147         ADOPTION          HEALTHY           HEALTHY    0
# 149  RETURN TO OWNER          UNKNOWN           PENDING    6
# 154         ADOPTION          HEALTHY           HEALTHY    0
# 158         ADOPTION          HEALTHY           HEALTHY    2
# 162         ADOPTION          HEALTHY           HEALTHY    0
# 164         ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB    0
# 170         ADOPTION  TREATABLE/REHAB           HEALTHY    0
# 174         ADOPTION  TREATABLE/REHAB   TREATABLE/REHAB    0
# 178         ADOPTION          HEALTHY           HEALTHY    9
# 183         ADOPTION          HEALTHY           HEALTHY    6
# 186         ADOPTION          HEALTHY           HEALTHY    0
# 195         ADOPTION          HEALTHY           HEALTHY    6
# 197         ADOPTION          HEALTHY           HEALTHY    0
# 200         ADOPTION          UNKNOWN           HEALTHY    0
# 207         ADOPTION          HEALTHY           HEALTHY   11
# 210         ADOPTION          HEALTHY           HEALTHY    0
# 212         ADOPTION          HEALTHY           HEALTHY    8
# 215         ADOPTION          HEALTHY           HEALTHY    0
# 216         ADOPTION          HEALTHY           HEALTHY    0
# 220         ADOPTION          HEALTHY           HEALTHY    0
# 229  RETURN TO OWNER          UNKNOWN           PENDING   -1
# 230  RETURN TO OWNER          UNKNOWN           PENDING    5
# 233         ADOPTION          HEALTHY           HEALTHY    0

# %%
# selecting rows that may matter for our prediction
new_df = df[['Breed', 'Sex', 'Age','Size','Intake Date', 'Intake Type', 'Intake Condition', 'Days in Shelter','Color']]
new_df
# Out:
#              Breed       Sex  Age   Size Intake Date      Intake Type  \
# 2      DOMESTIC LH  Neutered   10  SMALL  09/29/2023            STRAY
# 4      DOMESTIC SH    Spayed    0  KITTN  05/30/2023            STRAY
# 15     DOMESTIC SH  Neutered    0  KITTN  06/13/2023            STRAY
# 17     SIAMESE/MIX  Neutered    0  KITTN  09/12/2023  OWNER SURRENDER
# 20     DOMESTIC SH  Neutered    0  KITTN  08/01/2023            STRAY
# ...            ...       ...  ...    ...         ...              ...
# 26583  DOMESTIC SH  Neutered    9    MED  02/03/2016  OWNER SURRENDER
# 26585  DOMESTIC SH    Spayed    1  KITTN  09/15/2022  OWNER SURRENDER
# 26591  DOMESTIC SH  Neutered    4  KITTN  07/20/2019         TRANSFER
# 26601  DOMESTIC SH  Neutered    9  SMALL  08/14/2014            STRAY
# 26603  DOMESTIC SH    Spayed    1  KITTN  08/16/2022            STRAY
#
#       Intake Condition  Days in Shelter            Color
# 2              HEALTHY                1      BLACK/WHITE
# 4              UNKNOWN               70  ORG TABBY/WHITE
# 15             UNKNOWN               56            BLACK
# 17             HEALTHY               18          LYNX PT
# 20             UNKNOWN               60            BLACK
# ...                ...              ...              ...
# 26583          HEALTHY               16            BLACK
# 26585          HEALTHY               44  BRN TABBY/WHITE
# 26591          HEALTHY               10      WHITE/BLACK
# 26601          HEALTHY                9  BRN TABBY/WHITE
# 26603          HEALTHY               44       BLUE CREAM
#
# [5041 rows x 9 columns]

# %%
# checking the shape of our new dataset
print(new_df.shape)
# Out:
# (5041, 9)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
df = pd.read_csv('../dataset/Animal_Shelter_Intake_and_Outcome.csv')

# Set a frequency threshold (you can adjust this value based on your criteria)
frequency_threshold = 20

# Calculate the frequency of each unique value in the specified column
value_counts = df['Color'].value_counts()

# Identify values with frequency below the threshold
low_frequency_values = value_counts[value_counts < frequency_threshold].index

# Drop rows where the specified values are present in the specified column
df = df[~df['Color'].isin(low_frequency_values)]

# Plotting bar plot for 'Color' column
category_counts = df['Color'].value_counts()
category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize=(30, 25))

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
# ploting bar plot for sex column

category_counts = new_df['Sex'].value_counts()
category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.title('Sex Data Distribution')

# Display the plot
plt.show()

# %%
# ploting bar plot for age column
new_df['Age'].plot(bins=27, kind='hist', edgecolor='black')

# category_counts = new_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Data Distribution')

# # Display the plot
plt.show()

# %%
# Drop rows with 'X-LRG' and 'TOY' values in the 'Size' column
df = df[~df['Size'].isin(['X-LRG', 'TOY'])]

# Plotting bar plot for 'Intake_Condition' column
category_counts = df['Size'].value_counts()
category_counts.plot(kind='bar', color='green', edgecolor='black', figsize=(12, 8))

# Adding labels and title
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title('Size Data Distribution')

# Display the plot
plt.show()

# %%
# ploting bar plot for Intake_Condition column
category_counts = new_df['Intake Condition'].value_counts()
category_counts.plot(kind='bar', color='orange', edgecolor='black', figsize= (30,25))

# Adding labels and title
plt.xlabel('Intake Condition')
plt.ylabel('Frequency')
plt.title('Intake Condition Data Distribution')

# Display the plot
plt.show()

# %%
# ploting bar plot for days stayed column
# Calculate bin edges programmatically
bin_width = 30  # Adjust this based on your preference
min_value = int(np.floor(min(new_df['Days in Shelter']) / bin_width) * bin_width)
max_value = int(np.ceil(max(new_df['Days in Shelter']) / bin_width) * bin_width)
bins = range(min_value, max_value + bin_width, bin_width)

new_df['Days in Shelter'].plot(bins= bins, kind='hist', edgecolor='black', figsize= (30,20))

# category_counts = new_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Days in Shelter')
plt.ylabel('Frequency')
plt.title('Days stayed Data Distribution')

# # Display the plot
plt.show()

# %%
# Initialize LabelEncoders for each categorical column
label_encoders = {}
for column in ['Color', 'Sex', 'Intake Condition', 'Intake Type','Breed', 'Size']:
    label_encoders[column] = LabelEncoder()
    df[column + '_encoded'] = label_encoders[column].fit_transform(df[column])

# Define the transformer for other preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), ['Color_encoded', 'Sex_encoded', 'Intake Condition_encoded', 'Intake Type_encoded',
                                     'Breed_encoded','Size_encoded'])
        # Add more transformers for other columns if needed
    ],
    remainder='passthrough'  # Pass through the columns not specified
)

# Create a pipeline with LabelEncoder and other transformers
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

# Fit and transform the data
transformed_data = pipeline.fit_transform(df)

# The transformed_data now contains the encoded and scaled values
print(transformed_data)
# Out:
# [[-1.226874323854778 1.7019682897377477 1.0044789946676065 ... 94952.0
#   '94952(38.237, -122.640695)' 1]
#  [-0.9974956994260266 -0.0010519396903898098 -0.975399897124403 ...
#   94901.0 '94901(37.9702346, -122.5260879)' 1]
#  [-0.5387384505685241 -0.8525620544044585 1.0044789946676065 ... 95407.0
#   '95407(38.4127094, -122.7412153)' 1]
#  ...
#  [-0.4240491383541485 -0.0010519396903898098 -0.975399897124403 ...
#   95401.0 '95401(38.44366000000008, -122.72461629999998)' 1]
#  [-0.8445766164735258 0.8504581750236789 -0.975399897124403 ... 95403.0
#   '95403(38.47164440000006, -122.7398255)' 1]
#  [-1.226874323854778 0.8504581750236789 -0.975399897124403 ... 94952.0
#   '94952(38.237, -122.640695)' 1]]

# %%
df.head(50)
# Out:
#                       Name   Type                          Breed  \
# 1                      NaN    CAT                    DOMESTIC SH
# 2                SYLVESTER    CAT                    DOMESTIC LH
# 3                      NaN    CAT                    DOMESTIC SH
# 4                    *TESS    CAT                    DOMESTIC SH
# 5                      MIU    CAT                    DOMESTIC SH
# 6                    SANDY    DOG                     POODLE MIN
# 7                     YODA    DOG                            PUG
# 8                  *DAKOTA    DOG             SIBERIAN HUSKY/MIX
# 9                      NaN    CAT                    DOMESTIC SH
# 10                     NaN    CAT                    DOMESTIC SH
# 11                   KITTY    CAT                    DOMESTIC SH
# 12                    MEKA    DOG            SHIH TZU/POODLE MIN
# 13            HESS/WINSTON    DOG   GERM SHEPHERD/SIBERIAN HUSKY
# 14                  *EMILY    DOG                  GERM SHEPHERD
# 15            *MITEY MOUSE    CAT                    DOMESTIC SH
# 16                  STORMI    CAT                    DOMESTIC LH
# 17                   SNOWY    CAT                    SIAMESE/MIX
# 18                     NaN    CAT                    DOMESTIC SH
# 19                     NaN    CAT                    DOMESTIC SH
# 20                    *ULI    CAT                    DOMESTIC SH
# 21                     NaN    CAT                    DOMESTIC MH
# 22                  *SADEE    CAT                    DOMESTIC SH
# 23                    BABY    DOG   PARSON RUSS TER/CHIHUAHUA SH
# 24                *MAXWELL    CAT                    DOMESTIC MH
# 25                *RUSSELL    CAT                    DOMESTIC SH
# 26                    THOR    DOG                  LABRADOR RETR
# 27                     NaN    CAT                    DOMESTIC MH
# 28                 PERSEUS    DOG                   PIT BULL/MIX
# 29                    LILA    CAT                    DOMESTIC SH
# 30              CLOVER MAE    DOG                   PIT BULL/MIX
# 31                 DAIMOKU    DOG              LABRADOR RETR/MIX
# 32                   CEIGE    DOG         GERM SHEPHERD/PIT BULL
# 33                 LUCIFER    DOG                 FRENCH BULLDOG
# 34                     NaN    CAT                    DOMESTIC MH
# 35                    LOLA    DOG                  GERM SHEPHERD
# 36                   MANGO    DOG                  LABRADOR RETR
# 37                  *BRITT    CAT                    DOMESTIC SH
# 38                     NaN    CAT                    DOMESTIC MH
# 39                     NaN    CAT                    DOMESTIC MH
# 40                     NaN    CAT                    DOMESTIC MH
# 41                    *ONI    CAT                    DOMESTIC SH
# 42                    PING    CAT                    DOMESTIC SH
# 43                     NaN    CAT                    DOMESTIC MH
# 44                    BEAR    DOG                 GREAT PYRENEES
# 45                     NaN    DOG                       PIT BULL
# 46                     NaN  OTHER                            BAT
# 47  *CLARENCE PRICKLE PAWS    CAT                    DOMESTIC SH
# 48                     NaN    CAT                    DOMESTIC SH
# 49                    LUNA    DOG  LABRADOR RETR/DOBERMAN PINSCH
# 50                  WILLOW    DOG         LABRADOR RETR/PIT BULL
#
#               Color       Sex   Size Date Of Birth Impound Number  \
# 1             BLACK   Unknown  KITTN           NaN     K23-046275
# 2       BLACK/WHITE  Neutered  SMALL    09/29/2013     K23-046271
# 3         BRN TABBY      Male  KITTN    08/15/2023     K23-046281
# 4   ORG TABBY/WHITE    Spayed  KITTN    05/07/2023     K23-044867
# 5   BRN TABBY/WHITE    Female  SMALL    07/15/2012     K23-045417
# 6             WHITE  Neutered  SMALL           NaN     K23-044482
# 7              FAWN      Male  SMALL    08/11/2021     K23-045656
# 8             WHITE  Neutered  LARGE    05/10/2020     K22-041041
# 9        GRAY TABBY    Spayed  SMALL    08/03/2020     K23-045613
# 10        BRN TABBY      Male  KITTN    08/15/2023     K23-046287
# 11            BLACK  Neutered  SMALL    08/10/2010     K23-045239
# 12            BROWN    Spayed  SMALL    08/31/2008     K23-045653
# 13        BLACK/TAN      Male    MED    10/28/2022     K23-045643
# 14        BLACK/TAN    Spayed    MED    02/28/2022     K23-045484
# 15            BLACK  Neutered  KITTN    05/22/2023     K23-045015
# 16        BRN TABBY      Male  SMALL    02/12/2022     K23-045238
# 17          LYNX PT  Neutered  KITTN    05/13/2023     K23-045985
# 18        BRN TABBY      Male  KITTN    08/15/2023     K23-046289
# 19        BRN TABBY      Male  KITTN    08/15/2023     K23-046288
# 20            BLACK  Neutered  KITTN    07/13/2023     K23-045592
# 21     ORANGE/WHITE   Unknown  KITTN    08/30/2023     K23-046277
# 22  BRN TABBY/WHITE    Spayed  KITTN    07/13/2023     K23-045590
# 23        BLACK/TAN    Female  PUPPY    07/01/2023     K23-046169
# 24  BRN TABBY/WHITE  Neutered  SMALL    08/30/2021     K23-045749
# 25       GRAY TABBY  Neutered  KITTN    07/07/2023     K23-045970
# 26           YELLOW  Neutered  LARGE    09/03/2019     K23-045990
# 27        BRN TABBY      Male  KITTN           NaN     K23-045519
# 28       GRAY/WHITE  Neutered  LARGE    08/13/2019     K23-045264
# 29  BRN TABBY/WHITE      Male  SMALL    08/09/2015     K23-045660
# 30        RED/WHITE    Spayed    MED    04/09/2015     K17-025513
# 31            BROWN    Spayed    MED    07/18/2019     K23-045644
# 32         TRICOLOR  Neutered  LARGE    10/07/2019     K23-044474
# 33       GRAY/WHITE      Male  SMALL    02/14/2022     K23-045668
# 34        BRN TABBY      Male  KITTN    06/26/2023     K23-045522
# 35      BROWN/BLACK    Spayed    MED           NaN     K23-045868
# 36           YELLOW      Male    MED    06/09/2020     K23-045679
# 37           TORTIE    Spayed  SMALL    07/18/2021     K23-045440
# 38  BRN TABBY/WHITE      Male  KITTN    04/18/2023     K23-044921
# 39        BRN TABBY      Male  KITTN    04/18/2023     K23-044924
# 40       GRAY TABBY      Male  KITTN    04/15/2023     K23-044923
# 41        BRN TABBY      Male  KITTN    08/05/2023     K23-045944
# 42      BLACK/WHITE    Spayed  SMALL    04/27/2018     K23-044493
# 43      BLACK/WHITE    Female  KITTN    04/18/2023     K23-044922
# 44            WHITE      Male  LARGE           NaN     K23-045526
# 45       BR BRINDLE    Female    MED           NaN     K23-045377
# 46            BROWN   Unknown  SMALL           NaN     K23-045645
# 47  ORG TABBY/WHITE      Male  KITTN    07/18/2023     K23-045661
# 48           AGOUTI   Unknown  KITTN           NaN     K23-046312
# 49            BLACK    Spayed    MED    03/07/2015     K19-032155
# 50            BLACK    Spayed    MED    08/15/2016     K17-022551
#
#    Kennel Number Animal ID  ... Outcome Jurisdiction Outcome Zip Code  \
# 1      RECEIVING   A420799  ...            *PETALUMA          94952.0
# 2           CS05   A420773  ...        OUT OF COUNTY          94901.0
# 3           CI01   A420810  ...               COUNTY          95407.0
# 4          LOBBY   A417889  ...           SANTA ROSA          95404.0
# 5           CS06   A419086  ...           SANTA ROSA          95403.0
# 6      RECEIVING   A416957  ...               COUNTY          95403.0
# 7           DS72   A419516  ...               COUNTY          95404.0
# 8           DA39   A410831  ...               COUNTY          95403.0
# 9         COOLER   A419441  ...                  NaN              NaN
# 10          CA03   A420817  ...               COUNTY          95407.0
# 11           SMM   A418762  ...           SANTA ROSA          95403.0
# 12         TRUCK   A419515  ...               COUNTY          95472.0
# 13          DS83   A419501  ...               COUNTY          95446.0
# 14          DA16   A419226  ...             *WINDSOR          95492.0
# 15         LOBBY   A418221  ...           SANTA ROSA          95404.0
# 16           SMM   A418758  ...           SANTA ROSA          95403.0
# 17         LOBBY   A420264  ...               COUNTY          95492.0
# 18          CA03   A420819  ...               COUNTY          95407.0
# 19          CA03   A420818  ...               COUNTY          95407.0
# 20          CA03   A419416  ...               COUNTY          95492.0
# 21         TRUCK   A420803  ...            *PETALUMA          94952.0
# 22         LOBBY   A419414  ...             *WINDSOR          95492.0
# 23           SMM   A420558  ...               COUNTY          95472.0
# 24          CA02   A419755  ...        OUT OF COUNTY          94901.0
# 25         LOBBY   A420237  ...             *WINDSOR          95492.0
# 26          DS89   A420149  ...        OUT OF COUNTY          94804.0
# 27          CA03   A419307  ...            *PETALUMA          94952.0
# 28          DA28   A399917  ...           SANTA ROSA          95404.0
# 29          CS06   A419533  ...           SANTA ROSA          95407.0
# 30          DS78   A328759  ...           SANTA ROSA          95404.0
# 31          DS79   A418124  ...           SANTA ROSA          95401.0
# 32         DQ110   A399426  ...           SANTA ROSA          95404.0
# 33         DQ118   A419553  ...           SANTA ROSA          95405.0
# 34          CA03   A419310  ...            *PETALUMA          94952.0
# 35          DS51   A420084  ...           SANTA ROSA          95401.0
# 36         DQ110   A410133  ...           SANTA ROSA          95401.0
# 37          CA02   A419128  ...               COUNTY          95407.0
# 38          CI02   A418022  ...               COUNTY          95407.0
# 39          CI02   A418025  ...               COUNTY          95407.0
# 40          CI02   A418024  ...               COUNTY          95407.0
# 41          CI01   A420188  ...                  NaN              NaN
# 42          CA02   A417022  ...               COUNTY          95407.0
# 43          CI02   A418023  ...               COUNTY          95407.0
# 44         DQ114   A419312  ...               COUNTY          94923.0
# 45          DS93   A418993  ...                  NaN              NaN
# 46          EUTH   A419502  ...                  NaN              NaN
# 47          CA03   A419543  ...            *PETALUMA          94952.0
# 48     RECEIVING   A420866  ...            *PETALUMA          94952.0
# 49          DA16   A347800  ...               COUNTY          95446.0
# 50          DS80   A348471  ...               COUNTY          95446.0
#
#                                          Location Count Color_encoded  \
# 1                      94952(38.237, -122.640695)     1             4
# 2                 94901(37.9702346, -122.5260879)     1            10
# 3                 95407(38.4127094, -122.7412153)     1            22
# 4                       95404(38.44511, -122.708)     1            54
# 5          95403(38.47164440000006, -122.7398255)     1            24
# 6          95403(38.47164440000006, -122.7398255)     1            74
# 7                       95404(38.44511, -122.708)     1            37
# 8          95403(38.47164440000006, -122.7398255)     1            74
# 9                                             NaN     1            44
# 10                95407(38.4127094, -122.7412153)     1            22
# 11         95403(38.47164440000006, -122.7398255)     1             4
# 12                95472(38.4007555, -122.8277055)     1            25
# 13                  95446(38.503755, -122.993485)     1             9
# 14                   95492(38.541355, -122.80026)     1             9
# 15                      95404(38.44511, -122.708)     1             4
# 16         95403(38.47164440000006, -122.7398255)     1            22
# 17                   95492(38.541355, -122.80026)     1            50
# 18                95407(38.4127094, -122.7412153)     1            22
# 19                95407(38.4127094, -122.7412153)     1            22
# 20                   95492(38.541355, -122.80026)     1             4
# 21                     94952(38.237, -122.640695)     1            52
# 22                   95492(38.541355, -122.80026)     1            24
# 23                95472(38.4007555, -122.8277055)     1             9
# 24                94901(37.9702346, -122.5260879)     1            24
# 25                   95492(38.541355, -122.80026)     1            44
# 26                94804(37.9298426, -122.3436353)     1            83
# 27                     94952(38.237, -122.640695)     1            22
# 28                      95404(38.44511, -122.708)     1            47
# 29                95407(38.4127094, -122.7412153)     1            24
# 30                      95404(38.44511, -122.708)     1            60
# 31  95401(38.44366000000008, -122.72461629999998)     0            25
# 32                      95404(38.44511, -122.708)     1            72
# 33                   95405(38.443415, -122.69178)     1            47
# 34                     94952(38.237, -122.640695)     1            22
# 35                  95401(38.44366, -122.7246163)     1            26
# 36  95401(38.44366000000008, -122.72461629999998)     1            83
# 37                95407(38.4127094, -122.7412153)     1            69
# 38                95407(38.4127094, -122.7412153)     1            24
# 39                95407(38.4127094, -122.7412153)     1            22
# 40                95407(38.4127094, -122.7412153)     1            44
# 41                                            NaN     1            22
# 42                95407(38.4127094, -122.7412153)     1            10
# 43                95407(38.4127094, -122.7412153)     1            10
# 44                   94923(38.35046, -123.065245)     1            74
# 45                                            NaN     1            20
# 46                                            NaN     1            25
# 47                     94952(38.237, -122.640695)     1            54
# 48                     94952(38.237, -122.640695)     1             0
# 49                  95446(38.503755, -122.993485)     1             4
# 50                  95446(38.503755, -122.993485)     1             4
#
#    Sex_encoded Intake Condition_encoded Intake Type_encoded Breed_encoded  \
# 1            4                        3                   5           381
# 2            2                        0                   5           373
# 3            1                        3                   5           381
# 4            3                        3                   5           381
# 5            0                        3                   5           381
# 6            2                        3                   5           755
# 7            1                        0                   5           778
# 8            2                        0                   5           892
# 9            3                        3                   4           381
# 10           1                        3                   5           381
# 11           2                        3                   5           381
# 12           3                        3                   5           872
# 13           1                        3                   5           471
# 14           3                        0                   5           445
# 15           2                        3                   5           381
# 16           1                        3                   5           373
# 17           2                        0                   3           877
# 18           1                        3                   5           381
# 19           1                        3                   5           381
# 20           2                        3                   5           381
# 21           4                        3                   5           378
# 22           3                        0                   5           381
# 23           0                        3                   5           671
# 24           2                        0                   5           378
# 25           2                        0                   5           381
# 26           2                        3                   3           549
# 27           1                        2                   5           378
# 28           2                        0                   5           725
# 29           1                        3                   5           381
# 30           3                        3                   2           725
# 31           3                        0                   2           576
# 32           2                        3                   4           467
# 33           1                        3                   5           434
# 34           1                        2                   5           378
# 35           3                        3                   5           445
# 36           1                        0                   2           549
# 37           3                        0                   5           381
# 38           1                        3                   5           378
# 39           1                        3                   5           378
# 40           1                        3                   5           378
# 41           1                        3                   5           381
# 42           3                        0                   3           381
# 43           0                        3                   5           378
# 44           1                        3                   2           503
# 45           0                        3                   5           699
# 46           4                        3                   4           120
# 47           1                        3                   5           381
# 48           4                        3                   5           381
# 49           3                        0                   0           567
# 50           3                        0                   5           578
#
#    Size_encoded
# 1             0
# 2             4
# 3             0
# 4             0
# 5             4
# 6             4
# 7             4
# 8             1
# 9             4
# 10            0
# 11            4
# 12            4
# 13            2
# 14            2
# 15            0
# 16            4
# 17            0
# 18            0
# 19            0
# 20            0
# 21            0
# 22            0
# 23            3
# 24            4
# 25            0
# 26            1
# 27            0
# 28            1
# 29            4
# 30            2
# 31            2
# 32            1
# 33            4
# 34            0
# 35            2
# 36            2
# 37            4
# 38            0
# 39            0
# 40            0
# 41            0
# 42            4
# 43            0
# 44            1
# 45            2
# 46            4
# 47            0
# 48            0
# 49            2
# 50            2
#
# [50 rows x 30 columns]

# %%
# Initialize a dictionary to store mappings
mappings = {}

# Use classes_ attribute to get the mapping
original_columns = ['Color', 'Sex', 'Intake Condition', 'Intake Type','Breed', 'Size']
encoded_columns = ['Color_encoded', 'Sex_encoded', 'Intake Condition_encoded', 'Intake Type_encoded',
                                     'Breed_encoded','Size_encoded']

for col, encoded_col in zip(original_columns, encoded_columns):
    mappings[col] = dict(zip(label_encoders[col].classes_, label_encoders[col].transform(label_encoders[col].classes_)))

# Display the mappings
for col, mapping in mappings.items():
    print(f"{col} mapping:")
    print(mapping)
    print()
# Out:
# Color mapping:
# {'AGOUTI': 0, 'APRICOT': 1, 'BL BRINDLE': 2, 'BL BRINDLE/WHITE': 3, 'BLACK': 4, 'BLACK/BLACK': 5, 'BLACK/BROWN': 6, 'BLACK/GRAY': 7, 'BLACK/RED': 8, 'BLACK/TAN': 9, 'BLACK/WHITE': 10, 'BLK SMOKE': 11, 'BLK TABBY': 12, 'BLUE': 13, 'BLUE CREAM': 14, 'BLUE CREAM/CALICO': 15, 'BLUE CREAM/TORTIE': 16, 'BLUE MERLE': 17, 'BLUE PT': 18, 'BLUE/WHITE': 19, 'BR BRINDLE': 20, 'BR BRINDLE/WHITE': 21, 'BRN TABBY': 22, 'BRN TABBY/TORTIE': 23, 'BRN TABBY/WHITE': 24, 'BROWN': 25, 'BROWN/BLACK': 26, 'BROWN/RED': 27, 'BROWN/TAN': 28, 'BROWN/WHITE': 29, 'BUFF': 30, 'BUFF/WHITE': 31, 'CALICO': 32, 'CALICO/WHITE': 33, 'CHOCOLATE': 34, 'CHOCOLATE/WHITE': 35, 'CREAM': 36, 'FAWN': 37, 'FAWN/BLACK': 38, 'FAWN/WHITE': 39, 'FLAME PT': 40, 'GOLD': 41, 'GOLD/WHITE': 42, 'GRAY': 43, 'GRAY TABBY': 44, 'GRAY TABBY/WHITE': 45, 'GRAY/BLACK': 46, 'GRAY/WHITE': 47, 'LILAC PT': 48, 'LIVER/WHITE': 49, 'LYNX PT': 50, 'ORANGE': 51, 'ORANGE/WHITE': 52, 'ORG TABBY': 53, 'ORG TABBY/WHITE': 54, 'PINK': 55, 'RED': 56, 'RED/BLACK': 57, 'RED/BROWN': 58, 'RED/TAN': 59, 'RED/WHITE': 60, 'SEAL PT': 61, 'SEAL PT/WHITE': 62, 'SILVER': 63, 'SLVR TABBY': 64, 'TAN': 65, 'TAN/BLACK': 66, 'TAN/BROWN': 67, 'TAN/WHITE': 68, 'TORTIE': 69, 'TORTIE/BRN TABBY': 70, 'TORTIE/WHITE': 71, 'TRICOLOR': 72, 'TRICOLOR/WHITE': 73, 'WHITE': 74, 'WHITE/BLACK': 75, 'WHITE/BLUE': 76, 'WHITE/BR BRINDLE': 77, 'WHITE/BRN TABBY': 78, 'WHITE/BROWN': 79, 'WHITE/GRAY': 80, 'WHITE/RED': 81, 'WHITE/TAN': 82, 'YELLOW': 83, 'YELLOW/WHITE': 84}
#
# Sex mapping:
# {'Female': 0, 'Male': 1, 'Neutered': 2, 'Spayed': 3, 'Unknown': 4}
#
# Intake Condition mapping:
# {'HEALTHY': 0, 'TREATABLE/MANAGEABLE': 1, 'TREATABLE/REHAB': 2, 'UNKNOWN': 3, 'UNTREATABLE': 4}
#
# Intake Type mapping:
# {'ADOPTION RETURN': 0, 'BORN HERE': 1, 'CONFISCATE': 2, 'OWNER SURRENDER': 3, 'QUARANTINE': 4, 'STRAY': 5, 'TRANSFER': 6}
#
# Breed mapping:
# {'ABYSSINIAN': 0, 'ABYSSINIAN/MIX': 1, 'AFFENPINSCHER': 2, 'AFFENPINSCHER/MIX': 3, 'AIREDALE TERR': 4, 'AIREDALE TERR/MIX': 5, 'AKBASH': 6, 'AKBASH/MIX': 7, 'AKITA': 8, 'AKITA/ALASKAN HUSKY': 9, 'AKITA/ANATOL SHEPHERD': 10, 'AKITA/CHOW CHOW': 11, 'AKITA/GERM SHEPHERD': 12, 'AKITA/LABRADOR RETR': 13, 'AKITA/MIX': 14, 'AKITA/PIT BULL': 15, 'ALASK KLEE KAI': 16, 'ALASK MALAMUTE': 17, 'ALASK MALAMUTE/MIX': 18, 'ALASK MALAMUTE/SIBERIAN HUSKY': 19, 'ALASKAN HUSKY': 20, 'ALASKAN HUSKY/ALASK MALAMUTE': 21, 'ALASKAN HUSKY/AUST KELPIE': 22, 'ALASKAN HUSKY/AUST SHEPHERD': 23, 'ALASKAN HUSKY/BEAGLE': 24, 'ALASKAN HUSKY/BORDER COLLIE': 25, 'ALASKAN HUSKY/GERM SHEPHERD': 26, 'ALASKAN HUSKY/LABRADOR RETR': 27, 'ALASKAN HUSKY/MIX': 28, 'ALASKAN HUSKY/PIT BULL': 29, 'ALASKAN HUSKY/SHIBA INU': 30, 'ALASKAN MALAMUT': 31, 'ALPINE/MIX': 32, 'AM PIT BULL TER': 33, 'AM PIT BULL TER/BULLDOG': 34, 'AM PIT BULL TER/LABRADOR RETR': 35, 'AM PIT BULL TER/MIX': 36, 'AM PIT BULL TER/RHOD RIDGEBACK': 37, 'AMER BULLDOG': 38, 'AMER BULLDOG/AM PIT BULL TER': 39, 'AMER BULLDOG/BOXER': 40, 'AMER BULLDOG/DOGO ARGENTINO': 41, 'AMER BULLDOG/MIX': 42, 'AMER BULLDOG/PIT BULL': 43, 'AMER ESKIMO': 44, 'AMER ESKIMO/MIX': 45, 'AMER ESKIMO/POMERANIAN': 46, 'AMER FOXHOUND': 47, 'AMER FOXHOUND/GREAT PYRENEES': 48, 'AMER FOXHOUND/MIX': 49, 'AMER FOXHOUND/WHIPPET': 50, 'AMER SH/MIX': 51, 'AMERICAN': 52, 'AMERICAN SABLE/MIX': 53, 'AMERICAN STAFF': 54, 'AMERICAN STAFF/CHIHUAHUA SH': 55, 'AMERICAN STAFF/GERM SHEPHERD': 56, 'AMERICAN STAFF/MIX': 57, 'AMERICAN STAFF/PIT BULL': 58, 'AMERICAN/MIX': 59, 'AMERICAN/REX': 60, 'ANATOL SHEPHERD': 61, 'ANATOL SHEPHERD/MIX': 62, 'ANGORA-ENGLISH': 63, 'ANGORA-FRENCH/FLEMISH GIANT': 64, 'ANGORA-SATIN': 65, 'ANGORA-SATIN/MIX': 66, 'ANGUS': 67, 'ARABIAN': 68, 'ARAUCANA': 69, 'AUST CATTLE DOG': 70, 'AUST CATTLE DOG/AUST KELPIE': 71, 'AUST CATTLE DOG/BASENJI': 72, 'AUST CATTLE DOG/BELG MALINOIS': 73, 'AUST CATTLE DOG/BORDER COLLIE': 74, 'AUST CATTLE DOG/CATAHOULA': 75, 'AUST CATTLE DOG/CHIHUAHUA SH': 76, 'AUST CATTLE DOG/GERM SHEPHERD': 77, 'AUST CATTLE DOG/GREAT DANE': 78, 'AUST CATTLE DOG/LABRADOR RETR': 79, 'AUST CATTLE DOG/MIX': 80, 'AUST CATTLE DOG/PARSON RUSS TER': 81, 'AUST CATTLE DOG/PIT BULL': 82, 'AUST CATTLE DOG/QUEENSLAND HEEL': 83, 'AUST KELPIE': 84, 'AUST KELPIE/BORDER COLLIE': 85, 'AUST KELPIE/CATAHOULA': 86, 'AUST KELPIE/GERM SHEPHERD': 87, 'AUST KELPIE/MIX': 88, 'AUST KELPIE/PIT BULL': 89, 'AUST KELPIE/WHIPPET': 90, 'AUST SHEPHERD': 91, 'AUST SHEPHERD/AKITA': 92, 'AUST SHEPHERD/AMERICAN STAFF': 93, 'AUST SHEPHERD/AUST CATTLE DOG': 94, 'AUST SHEPHERD/BORDER COLLIE': 95, 'AUST SHEPHERD/BOXER': 96, 'AUST SHEPHERD/CHIHUAHUA SH': 97, 'AUST SHEPHERD/GERM SHEPHERD': 98, 'AUST SHEPHERD/GOLDEN RETR': 99, 'AUST SHEPHERD/LABRADOR RETR': 100, 'AUST SHEPHERD/MIX': 101, 'AUST SHEPHERD/PIT BULL': 102, 'AUST SHEPHERD/SIBERIAN HUSKY': 103, 'AUST SHEPHERD/WOLF': 104, 'AUST TERRIER': 105, 'AUST TERRIER/CHIHUAHUA LH': 106, 'AUST TERRIER/MIX': 107, 'AUST TERRIER/YORKSHIRE TERR': 108, 'BALINESE': 109, 'BALINESE/JAVANESE': 110, 'BARRED ROCK': 111, 'BASENJI': 112, 'BASENJI/MIX': 113, 'BASSET HOUND': 114, 'BASSET HOUND/BEAGLE': 115, 'BASSET HOUND/GERM SHEPHERD': 116, 'BASSET HOUND/MIX': 117, 'BASSET HOUND/PARSON RUSS TER': 118, 'BASSET HOUND/PIT BULL': 119, 'BAT': 120, 'BAT/MEX FREE-TAIL': 121, 'BEAGLE': 122, 'BEAGLE/AMERICAN STAFF': 123, 'BEAGLE/BOXER': 124, 'BEAGLE/CHIHUAHUA SH': 125, 'BEAGLE/FOX TERR SMOOTH': 126, 'BEAGLE/FOX TERR WIRE': 127, 'BEAGLE/GERM SHEPHERD': 128, 'BEAGLE/LABRADOR RETR': 129, 'BEAGLE/MIX': 130, 'BEAGLE/PARSON RUSS TER': 131, 'BEAGLE/PUG': 132, 'BEAGLE/RAT TERRIER': 133, 'BEAGLE/TOY FOX TERRIER': 134, 'BEAGLE/WELSH CORGI PEM': 135, 'BEARDED COLLIE/MIX': 136, 'BELG MALINOIS': 137, 'BELG MALINOIS/BELG TERVUREN': 138, 'BELG MALINOIS/CHESA BAY RETR': 139, 'BELG MALINOIS/GERM SHEPHERD': 140, 'BELG MALINOIS/MIX': 141, 'BELG TERVUREN': 142, 'BELG TERVUREN/GERM SHEPHERD': 143, 'BELG TERVUREN/MIX': 144, 'BELGIAN HARE/MIX': 145, 'BENGAL':  ...
#
# Size mapping:
# {'KITTN': 0, 'LARGE': 1, 'MED': 2, 'PUPPY': 3, 'SMALL': 4, nan: 5}

# %%
# Create DataFrames for each mapping
dfs = [pd.DataFrame({f"{col} (Original)": list(mapping.keys()), f"{encoded_col} (Encoded)": list(mapping.values())}) for col, mapping in mappings.items()]

# Concatenate DataFrames side by side
result_df = pd.concat(dfs, axis=1)

# Display the result DataFrame
print(result_df)
# Out:
#      Color (Original)  Size_encoded (Encoded) Sex (Original)  \
# 0              AGOUTI                     0.0         Female
# 1             APRICOT                     1.0           Male
# 2          BL BRINDLE                     2.0       Neutered
# 3    BL BRINDLE/WHITE                     3.0         Spayed
# 4               BLACK                     4.0        Unknown
# ..                ...                     ...            ...
# 966               NaN                     NaN            NaN
# 967               NaN                     NaN            NaN
# 968               NaN                     NaN            NaN
# 969               NaN                     NaN            NaN
# 970               NaN                     NaN            NaN
#
#      Size_encoded (Encoded) Intake Condition (Original)  \
# 0                       0.0                     HEALTHY
# 1                       1.0        TREATABLE/MANAGEABLE
# 2                       2.0             TREATABLE/REHAB
# 3                       3.0                     UNKNOWN
# 4                       4.0                 UNTREATABLE
# ..                      ...                         ...
# 966                     NaN                         NaN
# 967                     NaN                         NaN
# 968                     NaN                         NaN
# 969                     NaN                         NaN
# 970                     NaN                         NaN
#
#      Size_encoded (Encoded) Intake Type (Original)  Size_encoded (Encoded)  \
# 0                       0.0        ADOPTION RETURN                     0.0
# 1                       1.0              BORN HERE                     1.0
# 2                       2.0             CONFISCATE                     2.0
# 3                       3.0        OWNER SURRENDER                     3.0
# 4                       4.0             QUARANTINE                     4.0
# ..                      ...                    ...                     ...
# 966                     NaN                    NaN                     NaN
# 967                     NaN                    NaN                     NaN
# 968                     NaN                    NaN                     NaN
# 969                     NaN                    NaN                     NaN
# 970                     NaN                    NaN                     NaN
#
#                    Breed (Original)  Size_encoded (Encoded) Size (Original)  \
# 0                        ABYSSINIAN                       0           KITTN
# 1                    ABYSSINIAN/MIX                       1           LARGE
# 2                     AFFENPINSCHER                       2             MED
# 3                 AFFENPINSCHER/MIX                       3           PUPPY
# 4                     AIREDALE TERR                       4           SMALL
# ..                              ...                     ...             ...
# 966  YORKSHIRE TERR/PARSON RUSS TER                     966             NaN
# 967       YORKSHIRE TERR/POMERANIAN                     967             NaN
# 968       YORKSHIRE TERR/POODLE MIN                     968             NaN
# 969       YORKSHIRE TERR/POODLE TOY                     969             NaN
# 970                 YORKSHIRE TERRI                     970             NaN
#
#      Size_encoded (Encoded)
# 0                       0.0
# 1                       1.0
# 2                       2.0
# 3                       3.0
# 4                       4.0
# ..                      ...
# 966                     NaN
# 967                     NaN
# 968                     NaN
# 969                     NaN
# 970                     NaN
#
# [971 rows x 12 columns]

# %%
df.to_csv("../dataset/encoded_dataset_nov_17", index = False)

# %%
# Our data management libraries
import pandas as pd
import numpy as np
from datetime import datetime
# A basic visualization library
import matplotlib.pyplot as plt

# A great visualization library
import seaborn as sns

# Very important, this will make your charts appear in your notebook instead of in a new window.
# %matplotlib inline

# %% [markdown]
# ## Initializing the dataset

# %%
df = pd.read_csv('../dataset/Sonoma_County_California_dataset.csv')
df.head()
# Out:
#       Name Type        Breed             Color       Sex   Size Date Of Birth  \
# 0  *MINNIE  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    08/02/2023
# 1  *DEEDEE  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    07/20/2023
# 2   *MINDY  CAT  DOMESTIC MH         BRN TABBY    Spayed  SMALL    08/09/2023
# 3   *STING  CAT  DOMESTIC SH         BRN TABBY  Neutered  KITTN    07/29/2023
# 4    *TESS  CAT  DOMESTIC SH   ORG TABBY/WHITE    Spayed  KITTN    05/07/2023
#
#   Impound Number Kennel Number Animal ID  ...    Intake Subtype Outcome Type  \
# 0     K23-045840          CA03   A420013  ...  OVER THE COUNTER     ADOPTION
# 1     K23-046144         LOBBY   A420501  ...  OVER THE COUNTER     ADOPTION
# 2     K23-045723         LOBBY   A419695  ...  OVER THE COUNTER     ADOPTION
# 3     K23-045841      WESTFARM   A420014  ...  OVER THE COUNTER     ADOPTION
# 4     K23-044867         LOBBY   A417889  ...  OVER THE COUNTER     ADOPTION
#
#    Outcome Subtype Intake Condition Outcome Condition Intake Jurisdiction  \
# 0         SCAS WEB          UNKNOWN           HEALTHY          SANTA ROSA
# 1         SCAS WEB          HEALTHY           HEALTHY              COUNTY
# 2         SCAS WEB          HEALTHY           HEALTHY          SANTA ROSA
# 3         WESTFARM          UNKNOWN           HEALTHY          SANTA ROSA
# 4           WALKIN          UNKNOWN           HEALTHY              COUNTY
#
#   Outcome Jurisdiction Outcome Zip Code                      Location Count
# 0        OUT OF COUNTY          95461.0   95461(38.75402, -122.61931)     1
# 1             *WINDSOR          95492.0  95492(38.541355, -122.80026)     1
# 2             *WINDSOR          95492.0  95492(38.541355, -122.80026)     1
# 3           SANTA ROSA          95404.0     95404(38.44511, -122.708)     1
# 4           SANTA ROSA          95404.0     95404(38.44511, -122.708)     1
#
# [5 rows x 24 columns]

# %%
import pandas as pd
from datetime import datetime

# Assuming df is your DataFrame

# List of columns you want to drop
columns_to_drop = ['Name', 'Impound Number', 'Kennel Number',
                   'Intake Subtype', 'Outcome Subtype', 'Intake Jurisdiction',
                   'Outcome Jurisdiction', 'Outcome Zip Code', 'Location', 'Count']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# Filter rows where 'Type' is 'CAT'
df = df[df['Type'] == 'CAT']

# Filter rows where 'Outcome Type' is 'ADOPTION'
df = df[df['Outcome Type'] == 'ADOPTION']

# Filter rows where 'Sex' is not 'Unknown'
df = df[df['Sex'] != 'Unknown']

# Convert 'Date of Birth' to datetime format
df['Date Of Birth'] = pd.to_datetime(df['Date Of Birth'])
df['Intake Date'] = pd.to_datetime(df['Intake Date'])

# Calculate age based on the Intake date
df['Intake Age'] = (df['Intake Date'] - df['Date Of Birth']).astype('<m8[Y]')

# Drop rows with null values in the 'Age' column
df = df.dropna(subset=['Intake Age'])

# Convert age to integer
df['Intake Age'] = df['Intake Age'].astype(int)

# Display the DataFrame
df.head()
# Out:
#   Type        Breed             Color       Sex   Size Date Of Birth  \
# 0  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    2023-08-02
# 1  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    2023-07-20
# 2  CAT  DOMESTIC MH         BRN TABBY    Spayed  SMALL    2023-08-09
# 3  CAT  DOMESTIC SH         BRN TABBY  Neutered  KITTN    2023-07-29
# 4  CAT  DOMESTIC SH   ORG TABBY/WHITE    Spayed  KITTN    2023-05-07
#
#   Animal ID Intake Date Outcome Date  Days in Shelter      Intake Type  \
# 0   A420013  2023-08-29   11/18/2023               81            STRAY
# 1   A420501  2023-10-17   11/18/2023               32  OWNER SURRENDER
# 2   A419695  2023-08-16   11/18/2023               94            STRAY
# 3   A420014  2023-08-29   11/17/2023               80            STRAY
# 4   A417889  2023-05-30   08/08/2023               70            STRAY
#
#   Outcome Type Intake Condition Outcome Condition  Intake Age
# 0     ADOPTION          UNKNOWN           HEALTHY           0
# 1     ADOPTION          HEALTHY           HEALTHY           0
# 2     ADOPTION          HEALTHY           HEALTHY           0
# 3     ADOPTION          UNKNOWN           HEALTHY           0
# 4     ADOPTION          UNKNOWN           HEALTHY           0

# %%
df.head(500).sort_values(by ='Intake Age', ascending=False)
# Out:
#     Type        Breed            Color       Sex   Size Date Of Birth  \
# 358  CAT  DOMESTIC SH        BRN TABBY    Spayed  SMALL    2008-11-05
# 338  CAT  DOMESTIC LH        BRN TABBY  Neutered  SMALL    2007-09-20
# 86   CAT  DOMESTIC SH             BUFF    Spayed  SMALL    2013-02-12
# 258  CAT  DOMESTIC MH        ORG TABBY  Neutered  SMALL    2004-03-07
# 301  CAT  DOMESTIC LH           ORANGE    Spayed  SMALL    2006-07-14
# ..   ...          ...              ...       ...    ...           ...
# 173  CAT  DOMESTIC SH        BRN TABBY  Neutered  KITTN    2023-06-20
# 500  CAT  DOMESTIC SH  BRN TABBY/WHITE  Neutered  SMALL    2016-04-04
# 222  CAT  DOMESTIC SH          LYNX PT  Neutered  KITTN    2014-07-27
# 464  CAT  DOMESTIC SH      BLACK/WHITE  Neutered  KITTN    2014-07-27
# 35   CAT  DOMESTIC SH      BLACK/WHITE  Neutered  KITTN    2023-05-04
#
#     Animal ID Intake Date Outcome Date  Days in Shelter      Intake Type  \
# 358   A401265  2020-11-05   11/14/2020                9            STRAY
# 338   A203801  2018-11-01   01/08/2019               68  OWNER SURRENDER
# 86    A417259  2023-05-04   09/07/2023              126  OWNER SURRENDER
# 258   A020107  2015-03-07   03/19/2015               12  OWNER SURRENDER
# 301   A339598  2016-07-14   08/19/2016               36  OWNER SURRENDER
# ..        ...         ...          ...              ...              ...
# 173   A420503  2023-10-10   11/09/2023               30  OWNER SURRENDER
# 500   A343185  2016-10-04   10/15/2016               11            STRAY
# 222   A309484  2014-07-25   09/30/2014               67  OWNER SURRENDER
# 464   A309485  2014-07-25   10/04/2014               71  OWNER SURRENDER
# 35    A416917  2023-04-22   08/04/2023              104        BORN HERE
#
#     Outcome Type      Intake Condition     Outcome Condition  Intake Age
# 358     ADOPTION               UNKNOWN               PENDING          12
# 338     ADOPTION  TREATABLE/MANAGEABLE  TREATABLE/MANAGEABLE          11
# 86      ADOPTION               HEALTHY               HEALTHY          10
# 258     ADOPTION  TREATABLE/MANAGEABLE  TREATABLE/MANAGEABLE          10
# 301     ADOPTION               HEALTHY               HEALTHY          10
# ..           ...                   ...                   ...         ...
# 173     ADOPTION               HEALTHY               HEALTHY           0
# 500     ADOPTION               HEALTHY               HEALTHY           0
# 222     ADOPTION               HEALTHY               HEALTHY          -1
# 464     ADOPTION               HEALTHY               HEALTHY          -1
# 35      ADOPTION               UNKNOWN               HEALTHY          -1
#
# [500 rows x 15 columns]

# %%
# renaming columns title

# Use the rename method with a dictionary to specify the new column names
df.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)
df.head(10)
# Out:
#   type        breed             color       sex   size date_of_birth  \
# 0  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    2023-08-02
# 1  CAT  DOMESTIC SH  BRN TABBY/TORTIE    Spayed  KITTN    2023-07-20
# 2  CAT  DOMESTIC MH         BRN TABBY    Spayed  SMALL    2023-08-09
# 3  CAT  DOMESTIC SH         BRN TABBY  Neutered  KITTN    2023-07-29
# 4  CAT  DOMESTIC SH   ORG TABBY/WHITE    Spayed  KITTN    2023-05-07
# 5  CAT  DOMESTIC MH         BRN TABBY    Spayed  SMALL    2023-08-09
# 6  CAT  DOMESTIC SH             BLACK  Neutered  KITTN    2023-05-22
# 7  CAT  DOMESTIC MH             BLACK    Spayed  SMALL    2023-08-24
# 8  CAT  DOMESTIC SH             BLACK  Neutered  KITTN    2023-07-18
# 9  CAT  DOMESTIC LH        GRAY/WHITE  Neutered  KITTN    2015-08-11
#
#   animal_id intake_date outcome_date  days_in_shelter      intake_type  \
# 0   A420013  2023-08-29   11/18/2023               81            STRAY
# 1   A420501  2023-10-17   11/18/2023               32  OWNER SURRENDER
# 2   A419695  2023-08-16   11/18/2023               94            STRAY
# 3   A420014  2023-08-29   11/17/2023               80            STRAY
# 4   A417889  2023-05-30   08/08/2023               70            STRAY
# 5   A419696  2023-08-16   11/18/2023               94            STRAY
# 6   A418221  2023-06-13   08/08/2023               56            STRAY
# 7   A421033  2023-10-08          NaN                0            STRAY
# 8   A421316  2023-10-18   11/18/2023               31  OWNER SURRENDER
# 9   A327287  2015-09-22   11/04/2015               43            STRAY
#
#   outcome_type intake_condition outcome_condition  intake_age
# 0     ADOPTION          UNKNOWN           HEALTHY           0
# 1     ADOPTION          HEALTHY           HEALTHY           0
# 2     ADOPTION          HEALTHY           HEALTHY           0
# 3     ADOPTION          UNKNOWN           HEALTHY           0
# 4     ADOPTION          UNKNOWN           HEALTHY           0
# 5     ADOPTION          HEALTHY           HEALTHY           0
# 6     ADOPTION          UNKNOWN           HEALTHY           0
# 7     ADOPTION          HEALTHY           HEALTHY           0
# 8     ADOPTION          HEALTHY           HEALTHY           0
# 9     ADOPTION  TREATABLE/REHAB           HEALTHY           0

# %%
df.isnull().sum()
# Out:
# type                 0
# breed                0
# color                0
# sex                  0
# size                 0
# date_of_birth        0
# animal_id            0
# intake_date          0
# outcome_date         1
# days_in_shelter      0
# intake_type          0
# outcome_type         0
# intake_condition     0
# outcome_condition    1
# intake_age           0
# dtype: int64

# %% [markdown]
# # Data cleaning begins here

# %% [markdown]
# ### Creating new dataset for visualization with required columns only

# %% [markdown]
# ***Observation: 'color', 'sex','size', 'breed', 'intake_age', 'intake_condition', 'intake_type' , 'days_in_shelter' are the columns we need for our data model, so we will only select those***

# %%
selected_columns = ['color', 'sex','size', 'breed', 'intake_age', 'intake_condition', 'intake_type' , 'days_in_shelter']
selected_df = df[selected_columns]

# %%
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter
# 0          UNKNOWN            STRAY               81
# 1          HEALTHY  OWNER SURRENDER               32
# 2          HEALTHY            STRAY               94
# 3          UNKNOWN            STRAY               80
# 4          UNKNOWN            STRAY               70

# %% [markdown]
# ## check null values

# %%
# 1. Print the number of null rows we have in our dataframe.
print(selected_df.isnull().sum())
# Out:
# color               0
# sex                 0
# size                0
# breed               0
# intake_age          0
# intake_condition    0
# intake_type         0
# days_in_shelter     0
# dtype: int64

# %% [markdown]
# ## check for duplicate values

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(selected_df.duplicated().sum())
# Out:
# 474

# %%
# Check for duplicated rows considering all columns
duplicated_rows = selected_df.duplicated(keep=False)

# Print the rows that are duplicated
print("Duplicated Rows:")
print(selected_df[duplicated_rows])
# Out:
# Duplicated Rows:
#                 color       sex   size        breed  intake_age  \
# 2           BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 5           BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 12    BRN TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
# 15              BLACK    Spayed  KITTN  DOMESTIC SH           0
# 29        BLACK/WHITE    Spayed  KITTN  DOMESTIC SH           0
# ...               ...       ...    ...          ...         ...
# 3857       GRAY TABBY  Neutered  KITTN  DOMESTIC SH           0
# 3858        ORG TABBY  Neutered  SMALL  DOMESTIC SH           0
# 3859        BRN TABBY    Spayed  KITTN  DOMESTIC SH           0
# 3868        BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 3875       GRAY TABBY    Spayed  KITTN  DOMESTIC SH           0
#
#      intake_condition      intake_type  days_in_shelter
# 2             HEALTHY            STRAY               94
# 5             HEALTHY            STRAY               94
# 12            HEALTHY            STRAY               18
# 15            HEALTHY            STRAY               45
# 29            HEALTHY  OWNER SURRENDER                9
# ...               ...              ...              ...
# 3857          HEALTHY  OWNER SURRENDER                8
# 3858          HEALTHY  OWNER SURRENDER                6
# 3859          HEALTHY            STRAY               23
# 3868  TREATABLE/REHAB            STRAY               41
# 3875  TREATABLE/REHAB            STRAY               63
#
# [812 rows x 8 columns]

# %%
selected_df= selected_df.drop_duplicates(keep='first')

# %%
# Recheck the number of duplicate rows we have in our dataframe.
print(selected_df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Data ploting and visualization begins here

# %% [markdown]
# ### Graphing individual columns

# %%
# our working dataframe
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter
# 0          UNKNOWN            STRAY               81
# 1          HEALTHY  OWNER SURRENDER               32
# 2          HEALTHY            STRAY               94
# 3          UNKNOWN            STRAY               80
# 4          UNKNOWN            STRAY               70

# %%
# checking the shape of our new dataset
print(selected_df.shape)
# Out:
# (3397, 8)

# %% [markdown]
# ### Data Visualization and cleaning for 'age'

# %%
selected_df= selected_df[selected_df['intake_age']>= 0]

# %%
# ploting bar plot for age column
selected_df['intake_age'].plot(bins=27, kind='hist', edgecolor='black')

# category_counts = selected_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Intake Age')
plt.ylabel('Frequency')
plt.title('Intake Age Data Distribution')

# # Display the plot
plt.show()

# %%
age_category_counts = selected_df['intake_age'].value_counts()
age_category_counts
# Out:
# 0     2441
# 1      302
# 2      132
# 3       99
# 4       95
# 6       56
# 5       53
# 7       48
# 8       44
# 9       35
# 10      23
# 11      18
# 12      16
# 13       8
# 14       8
# 15       3
# Name: intake_age, dtype: int64

# %% [markdown]
# **Here we see histogram has outliers on right end and we need to remove these outliers for the sake of accurate prediction**

# %% [markdown]
# ## Data visualization after cleaning for 'age'

# %%
selected_df= selected_df[selected_df['intake_age']<=10]
age_category_counts2 = selected_df['intake_age'].value_counts()
age_category_counts2
# Out:
# 0     2441
# 1      302
# 2      132
# 3       99
# 4       95
# 6       56
# 5       53
# 7       48
# 8       44
# 9       35
# 10      23
# Name: intake_age, dtype: int64

# %%
# ploting bar plot for age column
selected_df['intake_age'].plot(bins=14, kind='hist', edgecolor='black')

# category_counts = selected_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Data Distribution')

# # Display the plot
plt.show()

# %% [markdown]
# ## Analysing primary_color column & ploting bar plot

# %%
color_category_counts = selected_df['color'].value_counts()
# Display the counts
print(color_category_counts)
# Out:
# BRN TABBY          462
# BLACK/WHITE        420
# BLACK              397
# BRN TABBY/WHITE    289
# GRAY TABBY         169
#                   ...
# WHITE/BLUE           1
# WHITE/TORTIE         1
# BLK TABBY/GRAY       1
# BLACK/BLK SMOKE      1
# BUFF/BROWN           1
# Name: color, Length: 100, dtype: int64

# %%
color_category_counts.plot(kind='bar', color='yellow', edgecolor='black', figsize= (30,25))

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Color Data Distribution')

# Display the plot
plt.show()

# %%
# Set display options to show all rows
pd.set_option('display.max_rows', None)

# Get the counts of unique values in the 'color' column
color_category_counts = selected_df['color'].value_counts()

# Convert the Series to a DataFrame for better display
color_category_counts_df = pd.DataFrame({'Color': color_category_counts.index, 'Count': color_category_counts.values})

# Display the DataFrame
print(color_category_counts_df)

# Reset display options to the default (if needed)
pd.reset_option('display.max_rows')
# Out:
#                     Color  Count
# 0               BRN TABBY    462
# 1             BLACK/WHITE    420
# 2                   BLACK    397
# 3         BRN TABBY/WHITE    289
# 4              GRAY TABBY    169
# 5              GRAY/WHITE    149
# 6                    GRAY    147
# 7               ORG TABBY    145
# 8                  TORTIE    127
# 9                 LYNX PT    100
# 10                 CALICO     74
# 11            WHITE/BLACK     72
# 12       GRAY TABBY/WHITE     72
# 13                SEAL PT     66
# 14        ORG TABBY/WHITE     52
# 15                   BUFF     43
# 16                 ORANGE     36
# 17             WHITE/GRAY     32
# 18        WHITE/BRN TABBY     32
# 19              BLK TABBY     32
# 20           ORANGE/WHITE     27
# 21      BLUE CREAM/TORTIE     25
# 22             BUFF/WHITE     24
# 23                  WHITE     24
# 24             BLUE CREAM     23
# 25       BRN TABBY/TORTIE     21
# 26               FLAME PT     21
# 27           CALICO/WHITE     17
# 28                BLUE PT     15
# 29           TORTIE/WHITE     14
# 30              BLK SMOKE     13
# 31               LILAC PT     11
# 32       TORTIE/BRN TABBY     10
# 33          SEAL PT/WHITE      9
# 34        BLK TABBY/WHITE      9
# 35              TORTIE PT      9
# 36       CALICO/BRN TABBY      9
# 37             SLVR TABBY      8
# 38      BLUE CREAM/CALICO      7
# 39              CHOCOLATE      6
# 40        WHITE/ORG TABBY      5
# 41        CHOCOLATE/WHITE      5
# 42      GRAY TABBY/TORTIE      5
# 43                  BROWN      4
# 44              CALICO PT      4
# 45           WHITE/ORANGE      4
# 46          LYNX PT/WHITE      3
# 47            BLACK/BLACK      3
# 48       BRN TABBY/CALICO      3
# 49      CALICO/BLUE CREAM      3
# 50              WHITE/TAN      3
# 51       BLUE CREAM/WHITE      3
# 52         LILAC PT/WHITE      3
# 53           WHITE/CALICO      2
# 54          BLUE PT/WHITE      2
# 55       SLVR TABBY/WHITE      2
# 56          CHOC PT/WHITE      2
# 57        BLK SMOKE/WHITE      2
# 58        BRN TABBY/BLACK      2
# 59          LYNX PT/CREAM      2
# 60        BLACK/BLK TABBY      2
# 61        TORTIE PT/WHITE      2
# 62                CHOC PT      2
# 63  GRAY TABBY/BLUE CREAM      2
# 64       BLK TABBY/TORTIE      2
# 65             WHITE/BUFF      2
# 66            TORTIE/GRAY      2
# 67            WHITE/BROWN      2
# 68        GRAY/BLUE CREAM      1
# 69            BROWN/WHITE      1
# 70         BRN TABBY/GRAY      1
# 71              CREAM/TAN      1
# 72             GRAY/BLACK      1
# 73              BRN TIGER      1
# 74         BUFF/ORG TABBY      1
# 75      CALICO/SLVR TABBY      1
# 76            ORANGE/BUFF      1
# 77          BRN TIGER/TAN      1
# 78        BRN TIGER/WHITE      1
# 79    BRN TABBY/ORG TABBY      1
# 80         WHITE/LILAC PT      1
# 81        CALICO PT/WHITE      1
# 82          BRN TABBY/RED      1
# 83       WHITE/GRAY TABBY      1
# 84          WHITE/SEAL PT      1
# 85          BLK TIGER/TAN      1
# 86       AGOUTI/BRN TABBY      1
# 87            CALICO/GRAY      1
# 88                   BLUE      1
# 89        BRN TABBY/CREAM      1
# 90            BLACK/BROWN      1
# 91       WHITE/BLUE TABBY      1
# 92            CREAM/WHITE      1
# 93      CALICO/GRAY TABBY      1
# 94              TAN/BLACK      1
# 95             WHITE/BLUE      1
# 96           WHITE/TORTIE      1
# 97         BLK TABBY/GRAY      1
# 98        BLACK/BLK SMOKE      1
# 99             BUFF/BROWN      1

# %% [markdown]
# ## Data cleaning for 'primary_color'

# %% [markdown]
# ### Simplifing the color categories

# %% [markdown]
# **we can see here we have about 99 different colors and most of them has very low frequency, so we will reduce the number of category by assigning to common categories**

# %%
def assign_color(input_string):
    if 'BRN TABBY' in input_string:
        return 'BRN_TABBY'
    elif 'ORG TABBY' in input_string:
        return 'ORG_TABBY'
    elif 'BLACK/WHITE' in input_string or 'WHITE/BLACK' in input_string:
        return 'BLACK_N_WHITE'
    elif 'GRAY/WHITE' in input_string or 'WHITE/GRAY' in input_string:
        return 'GRAY_N_WHITE'
    elif 'TORTIE' in input_string:
        return 'TORTIE'
    elif 'GRAY TABBY' in input_string:
        return 'GRAY_TABBY'
    elif 'TABBY' in input_string:
        return 'OTHER_TABBY'
    elif 'BLACK/BLACK' in input_string:
        return 'BLACK'
#     elif '/' in input_string or ' ' in input_string:
#         return 'MIX'
    else:
        return input_string

selected_df['simplified_color'] = selected_df['color'].apply(assign_color)

selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY

# %%
# def assign_color(input_string):
#     if 'TABBY' in input_string:
#         return 'TABBY'
#     elif '/' in input_string or ' ' in input_string:
#         return 'MIX'
#     else:
#         return 'ONE COLOR'

# selected_df['simplified_color'] = selected_df['color'].apply(assign_color)

# selected_df.head()

# %% [markdown]
# ## Data visualization after cleaning for 'color'

# %%
color_category_counts2 = selected_df['simplified_color'].value_counts()
color_category_counts2
# Set display options to show all rows
pd.set_option('display.max_rows', None)

# Get the counts of unique values in the 'color' column
color_category_counts2 = selected_df['simplified_color'].value_counts()

# Convert the Series to a DataFrame for better display
color_category_counts2_df = pd.DataFrame({'simplified_color': color_category_counts2.index, 'Count': color_category_counts2.values})

# Display the DataFrame
print(color_category_counts2_df)

# Reset display options to the default (if needed)
pd.reset_option('display.max_rows')
# Out:
#      simplified_color  Count
# 0           BRN_TABBY    833
# 1       BLACK_N_WHITE    492
# 2               BLACK    400
# 3          GRAY_TABBY    244
# 4           ORG_TABBY    203
# 5              TORTIE    187
# 6        GRAY_N_WHITE    182
# 7                GRAY    147
# 8             LYNX PT    100
# 9              CALICO     74
# 10            SEAL PT     66
# 11        OTHER_TABBY     56
# 12               BUFF     43
# 13             ORANGE     36
# 14       ORANGE/WHITE     27
# 15              WHITE     24
# 16         BUFF/WHITE     24
# 17         BLUE CREAM     23
# 18           FLAME PT     21
# 19       CALICO/WHITE     17
# 20            BLUE PT     15
# 21          BLK SMOKE     13
# 22           LILAC PT     11
# 23      SEAL PT/WHITE      9
# 24  BLUE CREAM/CALICO      7
# 25          CHOCOLATE      6
# 26    CHOCOLATE/WHITE      5
# 27              BROWN      4
# 28          CALICO PT      4
# 29       WHITE/ORANGE      4
# 30          WHITE/TAN      3
# 31   BLUE CREAM/WHITE      3
# 32      LYNX PT/WHITE      3
# 33  CALICO/BLUE CREAM      3
# 34     LILAC PT/WHITE      3
# 35      CHOC PT/WHITE      2
# 36        WHITE/BROWN      2
# 37      BLUE PT/WHITE      2
# 38    BLK SMOKE/WHITE      2
# 39       WHITE/CALICO      2
# 40      LYNX PT/CREAM      2
# 41            CHOC PT      2
# 42         WHITE/BUFF      2
# 43          BRN TIGER      1
# 44        ORANGE/BUFF      1
# 45        BROWN/WHITE      1
# 46      BRN TIGER/TAN      1
# 47    BRN TIGER/WHITE      1
# 48         GRAY/BLACK      1
# 49          CREAM/TAN      1
# 50     WHITE/LILAC PT      1
# 51    CALICO PT/WHITE      1
# 52      WHITE/SEAL PT      1
# 53      BLK TIGER/TAN      1
# 54               BLUE      1
# 55        BLACK/BROWN      1
# 56          TAN/BLACK      1
# 57         WHITE/BLUE      1
# 58        CREAM/WHITE      1
# 59    GRAY/BLUE CREAM      1
# 60    BLACK/BLK SMOKE      1
# 61        CALICO/GRAY      1
# 62         BUFF/BROWN      1

# %%
def assign_color(input_string):
    if '/' in input_string or ' ' in input_string:
        return 'MIX'
    else:
        return input_string

selected_df['simplified_color'] = selected_df['simplified_color'].apply(assign_color)

selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY

# %%
def assign_color(input_string):
    colors_to_check = ['BRN_TABBY', 'BLACK_N_WHITE', 'BLACK', 'MIX', 'GRAY_TABBY', 'ORG_TABBY', 'OTHER_TABBY', 'GRAY', 'TORTIE']
    
    if any(color in input_string for color in colors_to_check):
        return input_string
    else:
        return 'OTHER'

selected_df['simplified_color'] = selected_df['simplified_color'].apply(assign_color)
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY

# %%
color_category_counts2 = selected_df['simplified_color'].value_counts()
color_category_counts2
# Set display options to show all rows
pd.set_option('display.max_rows', None)

# Get the counts of unique values in the 'color' column
color_category_counts2 = selected_df['simplified_color'].value_counts()

# Convert the Series to a DataFrame for better display
color_category_counts2_df = pd.DataFrame({'simplified_color': color_category_counts2.index, 'Count': color_category_counts2.values})

# Display the DataFrame
print(color_category_counts2_df)

# Reset display options to the default (if needed)
pd.reset_option('display.max_rows')
# Out:
#    simplified_color  Count
# 0         BRN_TABBY    833
# 1     BLACK_N_WHITE    492
# 2             BLACK    400
# 3               MIX    396
# 4        GRAY_TABBY    244
# 5         ORG_TABBY    203
# 6             OTHER    188
# 7            TORTIE    187
# 8      GRAY_N_WHITE    182
# 9              GRAY    147
# 10      OTHER_TABBY     56

# %%
import matplotlib.pyplot as plt

# Assuming category_counts2 is your Series
# color_category_counts2 = pd.Series({'TABBY': 949, 'BLACK': 744, 'OTHER': 626, 'GRAY': 333, 'WHITE': 219})

# Create a color dictionary for each category
color_dict = {'BRN_TABBY': '#964B00', 'BLACK_N_WHITE':'#48494B', 'BLACK': 'black', 'MIX': '#CBC3E3', 'GRAY_TABBY': '#818380', 'ORG_TABBY':'orange', 'OTHER': 'white','TORTIE': 'blue', 'GRAY_N_WHITE': '#D6CFC7', 'GRAY': 'gray', 'OTHER_TABBY': 'red' }

# Plot the bar chart with specified colors
color_category_counts2.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in color_category_counts2.index])

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Simplified Cat Color Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## Analysing 'sex' column & ploting bar plot

# %%
sex_category_counts = selected_df['sex'].value_counts()
sex_category_counts
# Out:
# Neutered    1667
# Spayed      1651
# Male           5
# Female         5
# Name: sex, dtype: int64

# %%
# ploting bar plot for sex column

category_counts = selected_df['sex'].value_counts()
category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.title('Sex Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ### Removing male female type

# %%
selected_df= selected_df[selected_df['sex'] != ('Male' or 'Female')]
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY

# %%
def assign_sex(input_string):
    if 'Neutered'in input_string:
        return 'MALE'
    elif 'Spayed'in input_string:
        return 'FEMALE'

selected_df['simplified_sex'] = selected_df['sex'].apply(assign_sex)

selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
#
#   simplified_sex
# 0         FEMALE
# 1         FEMALE
# 2         FEMALE
# 3           MALE
# 4         FEMALE

# %% [markdown]
# ## Data visualization after cleaning for 'sex'

# %%
sex_category_counts = selected_df['simplified_sex'].value_counts()
sex_category_counts
# Out:
# MALE      1667
# FEMALE    1651
# Name: simplified_sex, dtype: int64

# %%
# ploting bar plot for simplified sex column

color_dict = {'MALE': 'blue', 'FEMALE': 'pink'}

# Plot the bar chart with specified colors
sex_category_counts.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in sex_category_counts.index])

# Adding labels and title
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.title('Sex Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## Data visualization & cleaning for 'intake_condition'

# %%
# ploting bar plot for Intake_Condition column
intake_condition_category_counts = selected_df['intake_condition'].value_counts()

intake_condition_category_counts.plot(kind='bar', color='orange', edgecolor='black', figsize= (30,25))

# Adding labels and title
plt.xlabel('Intake Condition')
plt.ylabel('Frequency')
plt.title('Intake Condition Data Distribution')

# Display the plot
plt.show()

# %%
intake_condition_category_counts
# Out:
# HEALTHY                 2159
# TREATABLE/REHAB          680
# UNKNOWN                  358
# TREATABLE/MANAGEABLE     119
# UNTREATABLE                7
# Name: intake_condition, dtype: int64

# %%
def assign_condition(input_string):    
    if 'HEALTHY' in input_string:
        return input_string
    elif 'UNTREATABLE' in input_string:
        return 'OTHER'
    elif 'TREATABLE' in input_string:
        return 'ILL'
    else:
        return 'OTHER'

selected_df['simplified_condition'] = selected_df['intake_condition'].apply(assign_condition)
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
#
#   simplified_sex simplified_condition
# 0         FEMALE                OTHER
# 1         FEMALE              HEALTHY
# 2         FEMALE              HEALTHY
# 3           MALE                OTHER
# 4         FEMALE                OTHER

# %% [markdown]
# ## Data visualization after cleaning for 'intake condition'

# %%
intake_condition_category_counts2 = selected_df['simplified_condition'].value_counts()
intake_condition_category_counts2
# Out:
# HEALTHY    2159
# ILL         799
# OTHER       365
# Name: simplified_condition, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a color dictionary for each category
color_dict = {'HEALTHY': 'green','OTHER': 'white', 'INJURED': 'gray', 'ILL': 'orange'}

# Plot the bar chart with specified colors
intake_condition_category_counts2.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in intake_condition_category_counts2.index])

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Simplified Cat Intake Condition Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## Data visualization and cleaning for 'intake type'

# %%
# ploting bar plot for Intake Type column

intake_type_category_counts = selected_df['intake_type'].value_counts()
intake_type_category_counts.plot(kind='bar', color='red', edgecolor='black', figsize= (20,20))

# Adding labels and title
plt.xlabel('Intake Type')
plt.ylabel('Frequency')
plt.title('Intake Type Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# **At this point I don't think Intake Type has any significance on prediction**

# %%
intake_type_category_counts
# Out:
# STRAY              2061
# OWNER SURRENDER     995
# ADOPTION RETURN      99
# TRANSFER             91
# CONFISCATE           67
# QUARANTINE           10
# Name: intake_type, dtype: int64

# %%
def assign_type(input_string):
    type_to_check = ['STRAY', 'OWNER SURRENDER']
    
    if any(condition in input_string for condition in type_to_check):
        return input_string
    else:
        return 'OTHER'

selected_df['simplified_type'] = selected_df['intake_type'].apply(assign_type)
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 2         BRN TABBY    Spayed  SMALL  DOMESTIC MH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 2          HEALTHY            STRAY               94        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
#
#   simplified_sex simplified_condition  simplified_type
# 0         FEMALE                OTHER            STRAY
# 1         FEMALE              HEALTHY  OWNER SURRENDER
# 2         FEMALE              HEALTHY            STRAY
# 3           MALE                OTHER            STRAY
# 4         FEMALE                OTHER            STRAY

# %% [markdown]
# ## Data visualization after cleaning for 'intake type'

# %%
intake_type_category_counts2 = selected_df['simplified_type'].value_counts()
intake_type_category_counts2
# Out:
# STRAY              2061
# OWNER SURRENDER     995
# OTHER               267
# Name: simplified_type, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a color dictionary for each category
color_dict = {'STRAY': 'green', 'OTHER': 'white', 'OWNER SURRENDER': 'red'}

# Plot the bar chart with specified colors
intake_type_category_counts2.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in intake_type_category_counts2.index])

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Simplified Cat Intake Type Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## Data visualization and cleaning for 'days stayed'

# %%
# ploting bar plot for days stayed column
# Calculate bin edges programmatically
bin_width = 30  # Adjust this based on your preference
min_value = int(np.floor(min(selected_df['days_in_shelter']) / bin_width) * bin_width)
max_value = int(np.ceil(max(selected_df['days_in_shelter']) / bin_width) * bin_width)
bins = range(min_value, max_value + bin_width, bin_width)

selected_df['days_in_shelter'].plot(bins= bins, kind='hist', edgecolor='black', figsize= (30,20))

# category_counts = selected_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('days_in_shelter')
plt.ylabel('Frequency')
plt.title('Days stayed Data Distribution')

# # Display the plot
plt.show()

# %% [markdown]
# **Here we see a good amount of the cat leaves shelter with in a month and most of them leaves by 4 months. But for some exceptional cases cat stays upto several months, and we have to remove outliers for these cases**

# %% [markdown]
# ## Data visualization after cleaning for 'days stayed'

# %%
selected_df = selected_df[selected_df['days_in_shelter']<90]

bin_width = 30  # Adjust this based on your preference
min_value = int(np.floor(min(selected_df['days_in_shelter']) / bin_width) * bin_width)
max_value = int(np.ceil(max(selected_df['days_in_shelter']) / bin_width) * bin_width)
bins = range(min_value, max_value + bin_width, bin_width)

selected_df['days_in_shelter'].plot(bins= bins, kind='hist', edgecolor='black', figsize= (30,20))

# category_counts = selected_df['Sex'].value_counts()
# category_counts.plot(kind='bar', color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('days_in_shelter')
plt.ylabel('Frequency')
plt.title('Days stayed Data Distribution')

# # Display the plot
plt.show()

# %%
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
# 6             BLACK  Neutered  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
# 6          UNKNOWN            STRAY               56            BLACK
#
#   simplified_sex simplified_condition  simplified_type
# 0         FEMALE                OTHER            STRAY
# 1         FEMALE              HEALTHY  OWNER SURRENDER
# 3           MALE                OTHER            STRAY
# 4         FEMALE                OTHER            STRAY
# 6           MALE                OTHER            STRAY

# %% [markdown]
# ## Data visualization & cleaning for 'size'

# %%
# ploting bar plot for Intake_Condition column
breed_category_counts = selected_df['breed'].value_counts()

breed_category_counts.plot(kind='bar', color='orange', edgecolor='black', figsize= (30,25))

# Adding labels and title
plt.xlabel('Cat Breed')
plt.ylabel('Frequency')
plt.title('Breed Data Distribution')

# Display the plot
plt.show()

# %%
breed_category_counts
# Out:
# DOMESTIC SH                2475
# DOMESTIC MH                 372
# DOMESTIC LH                 223
# SIAMESE/MIX                  80
# SIAMESE                      72
# HIMALAYAN                     7
# MANX                          6
# ABYSSINIAN/MIX                5
# HIMALAYAN/MIX                 5
# DOMESTIC SH/MIX               5
# SNOWSHOE/MIX                  5
# SNOWSHOE                      4
# MANX/MIX                      3
# DOMESTIC LH/MAINE COON        3
# SCOTTISH FOLD/MIX             3
# PERSIAN                       2
# PERSIAN/MIX                   2
# BENGAL/DOMESTIC SH            2
# TURKISH ANGORA                2
# OCICAT                        1
# SIAMESE/DOMESTIC LH           1
# BRITISH SH                    1
# MAINE COON/MIX                1
# BURMESE                       1
# BALINESE                      1
# SNOWSHOE/SIAMESE              1
# BURMESE/MIX                   1
# TURKISH VAN/MIX               1
# DOMESTIC SH/ABYSSINIAN        1
# EXOTIC SH                     1
# SCOTTISH FOLD                 1
# SIAMESE/DOMESTIC SH           1
# DOMESTIC MH/DOMESTIC LH       1
# DOMESTIC MH/MIX               1
# DOMESTIC LH/SIAMESE           1
# ABYSSINIAN/DOMESTIC SH        1
# DOMESTIC SH/DOMESTIC SH       1
# Name: breed, dtype: int64

# %%
def assign_breed(input_string):
#     conditions_to_check = ['NORMAL', 'ILL MILD', 'ILL SEVERE']
    
    if 'DOMESTIC SH' in input_string:
        return 'DOMESTIC_SHORT_HAIR'
    elif 'DOMESTIC MH' in input_string or 'DOMESTIC LH' in input_string:
        return 'DOMESTIC_MED_OR_LONG_HAIR'
    else:
        return 'OTHER'

selected_df['simplified_breed'] = selected_df['breed'].apply(assign_breed)
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
# 6             BLACK  Neutered  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
# 6          UNKNOWN            STRAY               56            BLACK
#
#   simplified_sex simplified_condition  simplified_type     simplified_breed
# 0         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 1         FEMALE              HEALTHY  OWNER SURRENDER  DOMESTIC_SHORT_HAIR
# 3           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 4         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 6           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR

# %% [markdown]
# ## Data visualization after cleaning for 'breed'

# %%
breed_category_counts2 = selected_df['simplified_breed'].value_counts()
breed_category_counts2
# Out:
# DOMESTIC_SHORT_HAIR          2441
# DOMESTIC_MED_OR_LONG_HAIR     593
# OTHER                         205
# Name: simplified_breed, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a color dictionary for each category
color_dict = {'DOMESTIC_SHORT_HAIR': 'orange', 'DOMESTIC_MED_OR_LONG_HAIR': 'blue', 'OTHER': 'white'}

# Plot the bar chart with specified colors
breed_category_counts2.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in breed_category_counts2.index])

# Adding labels and title
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.title('Simplified Cat Breed Data Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## Data visualization & cleaning for 'size'

# %%
# ploting bar plot for Intake_Condition column
size_category_counts = selected_df['size'].value_counts()

size_category_counts.plot(kind='bar', color='orange', edgecolor='black', figsize= (30,25))

# Adding labels and title
plt.xlabel('Cat Size')
plt.ylabel('Frequency')
plt.title('Cat Size Data Distribution')

# Display the plot
plt.show()

# %%
size_category_counts
# Out:
# KITTN    1859
# SMALL    1371
# MED        34
# LARGE      27
# X-LRG       2
# TOY         1
# Name: size, dtype: int64

# %%
def assign_size(input_string):
    size_to_check = ['KITTN', 'SMALL']
    
    if any(size in input_string for size in size_to_check):
        return input_string
    else:
        return 'OTHER'

selected_df['simplified_size'] = selected_df['size'].apply(assign_size)
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
# 6             BLACK  Neutered  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
# 6          UNKNOWN            STRAY               56            BLACK
#
#   simplified_sex simplified_condition  simplified_type     simplified_breed  \
# 0         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 1         FEMALE              HEALTHY  OWNER SURRENDER  DOMESTIC_SHORT_HAIR
# 3           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 4         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 6           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
#
#   simplified_size
# 0           KITTN
# 1           KITTN
# 3           KITTN
# 4           KITTN
# 6           KITTN

# %% [markdown]
# ## Data visualization after cleaning for 'intake condition'

# %%
size_category_counts2 = selected_df['simplified_size'].value_counts()
size_category_counts2
# Out:
# KITTN    1840
# SMALL    1337
# OTHER      62
# Name: simplified_size, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a color dictionary for each category
color_dict = {'KITTN': 'green','OTHER': 'white', 'SMALL': 'orange'}

# Plot the bar chart with specified colors
size_category_counts2.plot(kind='bar', edgecolor='black', figsize=(10, 6), color=[color_dict.get(x, 'blue') for x in size_category_counts2.index])

# Adding labels and title
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.title('Simplified Cat Intake Condition Data Distribution')

# Display the plot
plt.show()

# %%
selected_df.head()
# Out:
#               color       sex   size        breed  intake_age  \
# 0  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 1  BRN TABBY/TORTIE    Spayed  KITTN  DOMESTIC SH           0
# 3         BRN TABBY  Neutered  KITTN  DOMESTIC SH           0
# 4   ORG TABBY/WHITE    Spayed  KITTN  DOMESTIC SH           0
# 6             BLACK  Neutered  KITTN  DOMESTIC SH           0
#
#   intake_condition      intake_type  days_in_shelter simplified_color  \
# 0          UNKNOWN            STRAY               81        BRN_TABBY
# 1          HEALTHY  OWNER SURRENDER               32        BRN_TABBY
# 3          UNKNOWN            STRAY               80        BRN_TABBY
# 4          UNKNOWN            STRAY               70        ORG_TABBY
# 6          UNKNOWN            STRAY               56            BLACK
#
#   simplified_sex simplified_condition  simplified_type     simplified_breed  \
# 0         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 1         FEMALE              HEALTHY  OWNER SURRENDER  DOMESTIC_SHORT_HAIR
# 3           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 4         FEMALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
# 6           MALE                OTHER            STRAY  DOMESTIC_SHORT_HAIR
#
#   simplified_size
# 0           KITTN
# 1           KITTN
# 3           KITTN
# 4           KITTN
# 6           KITTN

# %%
selected_columns = ['simplified_color', 'simplified_sex', 'intake_age', 'simplified_condition','simplified_type','simplified_breed', 'simplified_size', 'days_in_shelter']

selected_df = selected_df[selected_columns]
selected_df.head()
# Out:
#   simplified_color simplified_sex  intake_age simplified_condition  \
# 0        BRN_TABBY         FEMALE           0                OTHER
# 1        BRN_TABBY         FEMALE           0              HEALTHY
# 3        BRN_TABBY           MALE           0                OTHER
# 4        ORG_TABBY         FEMALE           0                OTHER
# 6            BLACK           MALE           0                OTHER
#
#    simplified_type     simplified_breed simplified_size  days_in_shelter
# 0            STRAY  DOMESTIC_SHORT_HAIR           KITTN               81
# 1  OWNER SURRENDER  DOMESTIC_SHORT_HAIR           KITTN               32
# 3            STRAY  DOMESTIC_SHORT_HAIR           KITTN               80
# 4            STRAY  DOMESTIC_SHORT_HAIR           KITTN               70
# 6            STRAY  DOMESTIC_SHORT_HAIR           KITTN               56

# %% [markdown]
# # Exporting cleaned dataset

# %%
selected_df.to_csv("../dataset/sonoma_county_cleaned_data_nov_29.csv", index = False)
